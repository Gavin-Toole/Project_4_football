# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\avila\anaconda3\lib\site-packages (2.9.6)

# %%
from flask import Flask, render_template, jsonify
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import sqlalchemy
from sqlalchemy import inspect
from pprint import pprint
import pandas as pd

# %%
# Database Setup
url= "postgresql://skbuqieh:YXm0YsioQnkqxA92fuujM6M9ozp8sLi5@ruby.db.elephantsql.com/skbuqieh"
engine = create_engine(url)

# %%
table_name = "Sunburst"
sunburst_data = pd.read_sql("select * from sunburst_data", engine.connect())

# %%
sunburst_LaLiga = sunburst_data.query('league =="LaLiga"')

# %%
sunburst_LaLiga.head()
# Out:
#       league  league_total_goals    squad  squad_total_goals
# 685   LaLiga              4782.0  AlavÃ©s              180.0  \
# 1408  LaLiga              4782.0  AlavÃ©s              180.0
# 1409  LaLiga              4782.0  AlavÃ©s              180.0
# 1410  LaLiga              4782.0  AlavÃ©s              180.0
# 1411  LaLiga              4782.0  AlavÃ©s              180.0
#
#       player_total_goal           player    id
# 685                 7.0   Ã‰dgar MÃ©ndez  1408
# 1408                2.0      Aleix Vidal  1409
# 1409                1.0           Alexis  1410
# 1410                3.0  Alfonso Pedraza  1411
# 1411                2.0  Ãlvaro MedrÃ¡n  1412

# %%
sunburst_LaLiga.groupby('squad')['player'].unique()
# Out:
# squad
# AlavÃ©s             [Ã‰dgar MÃ©ndez, Aleix Vidal, Alexis, Alfonso ...
# Athletic Club       [Ã“scar de Marcos, Ãlex Berenguer, Ander Capa...
# AtlÃ©tico Madrid    [Å ime Vrsaljko, Ãlvaro Morata, Ãngel Correa...
# Barcelona           [Ã“scar Mingueza, Abdessamad Ezzalzouli, Aleix...
# Betis               [Ã‰dgar GonzÃ¡lez, AÃ¯ssa Mandi, Aitor Ruibal,...
# Celta Vigo          [Augusto Solari, Brais MÃ©ndez, Daniel Wass, D...
# CÃ¡diz              [Alberto Perea, Ãlex FernÃ¡ndez, Alfonso Espi...
# Eibar               [Ãlex GÃ¡lvez, Anaitz Arbilla, Bryan, Charles...
# Elche               [Dani Calvo, DarÃ­o Benedetto, Diego GonzÃ¡lez...
# Espanyol            [Adri Embarba, Aleix Vidal, Bernardo Espinosa,...
# Getafe              [Allan Nyom, Ãlvaro JimÃ©nez, Amath, Ãngel R...
# Girona              [Aday, Aleix GarcÃ­a, Ãlex Granell, Anthony L...
# Granada             [Alberto Soro, Ãlex Collado, Ãlvaro Vadillo,...
# Huesca              [Ãlex Gallar, Borja GarcÃ­a, Cristian Rivera,...
# La CoruÃ±a          [AdriÃ¡n LÃ³pez, Borja Valle, Celso Borges, Em...
# Las Palmas          [Alen HaliloviÄ‡, David GarcÃ­a, Erik ExpÃ³sit...
# LeganÃ©s            [Ã“scar RodrÃ­guez Arnaiz, Alexander, Allan Ny...
# Levante             [Ã“scar Duarte, Borja Mayoral, Cheick DoukourÃ...
# Mallorca            [AbdÃ³n Prats, Alejandro Pozo Pozo, Ãngel Rod...
# MÃ¡laga             [AdriÃ¡n GonzÃ¡lez, Borja BastÃ³n, Brown Ideye...
# Osasuna             [AdriÃ¡n LÃ³pez, Ante Budimir, Aridane HernÃ¡n...
# Rayo Vallecano      [Ã“scar Trejo, Abdoulaye Ba, Adri Embarba, Ãl...
# Real Madrid         [Ã‰der MilitÃ£o, Achraf Hakimi, Ãlvaro Odrioz...
# Real Sociedad       [Adnan Januzaj, Alexander Isak, Alexander SÃ¸r...
# Sevilla             [Ã“liver Torres, Ã‰rik Lamela, Ã‰ver Banega, A...
# Valencia            [Alejandro Blanco, Andreas Pereira, Carlos Sol...
# Valladolid          [Ã“scar Plano, AntoÃ±ito, Anuar, Bruno GonzÃ¡l...
# Villarreal          [Ã‰tienne Capoue, AÃ¯ssa Mandi, Alberto Moreno...
# Name: player, dtype: object

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
#Base.metadata.tables
Base.classes.keys()
# table_names = Base.metadata.tables.keys()
# print(table_names)
# Stadiums = Base.classes.stadiums_data
# Sunburst = Base.classes.sunburst_data
# Wages = Base.classes.league_wages
# Points = Base.classes.league_pts
# Out:
# ['stadiums_data', 'league_wages', 'league_pts', 'sunburst_data']

# %%
engine.url.database
# Out:
# 'skbuqieh'

# %%
Stadiums = Base.classes.stadiums_data
Sunburst = Base.classes.sunburst_data
Wages = Base.classes.league_wages
Points = Base.classes.league_pts

# %%
inspector = inspect(engine)
columns_sunburst = inspector.get_columns('sunburst_data')
for column in columns_sunburst:
    print(column['name'], column['type'])
# Out:
# league VARCHAR(255)
# league_total_goals DOUBLE_PRECISION
# squad VARCHAR(255)
# squad_total_goals DOUBLE_PRECISION
# player_total_goal DOUBLE_PRECISION
# player VARCHAR(255)
# id INTEGER

# %%
session = Session(engine)

# %%
sunburst_data = session.query(Sunburst.league, Sunburst.league_total_goals, Sunburst.squad, Sunburst.squad_total_goals, Sunburst.player, Sunburst.player_total_goal)\
        .filter(Sunburst.league == 'LaLiga')\
        .order_by(Sunburst.squad_total_goals.desc(), Sunburst.player_total_goal.desc()).all()

# %%
sunburst_data.groupby()
# Out:
# [('LaLiga', 4782.0, 'Barcelona', 428.0, 'Lionel Messi', 125.0),
#  ('LaLiga', 4782.0, 'Barcelona', 428.0, 'Luis SuÃ¡rez', 62.0),
#  ('LaLiga', 4782.0, 'Barcelona', 428.0, 'Antoine Griezmann', 22.0),
#  ('LaLiga', 4782.0, 'Barcelona', 428.0, 'Ousmane DembÃ©lÃ©', 19.0),
#  ('LaLiga', 4782.0, 'Barcelona', 428.0, 'Philippe Coutinho', 17.0),
#  ('LaLiga', 4782.0, 'Barcelona', 428.0, 'Ansu Fati', 15.0),
#  ('LaLiga', 4782.0, 'Barcelona', 428.0, 'Memphis', 12.0),
#  ('LaLiga', 4782.0, 'Barcelona', 428.0, 'Jordi Alba', 11.0),
#  ('LaLiga', 4782.0, 'Barcelona', 428.0, 'Pierre-Emerick Aubameyang', 11.0),
#  ('LaLiga', 4782.0, 'Barcelona', 428.0, 'Arturo Vidal', 11.0)]

# %%
result = {
    'league_name': sunburst_data[0][0],
    'league_goals': sunburst_data[0][1],
    'teams': []
}

team_dict = {}

for row in sunburst_data:
    squad_name = row.squad
    squad_goals = row.squad_total_goals
    player_name = row.player
    player_goals = row.player_total_goal
    
    if squad_name not in team_dict.values():
    
        team_dict = {'squad_name': squad_name, 
                    'squad_goals': squad_goals,
                    'players': []}

        result['teams'].append(team_dict)
    
    player_dict = {'player_name': player_name,
                   'player_goals': player_goals}
    
    team_dict['players'].append(player_dict)

# %%
result
# Out:
# {'league_name': 'LaLiga',
#  'league_goals': 4782.0,
#  'teams': [{'squad_name': 'Barcelona',
#    'squad_goals': 428.0,
#    'players': [{'player_name': 'Lionel Messi', 'player_goals': 125.0},
#     {'player_name': 'Luis SuÃ¡rez', 'player_goals': 62.0},
#     {'player_name': 'Antoine Griezmann', 'player_goals': 22.0},
#     {'player_name': 'Ousmane DembÃ©lÃ©', 'player_goals': 19.0},
#     {'player_name': 'Philippe Coutinho', 'player_goals': 17.0},
#     {'player_name': 'Ansu Fati', 'player_goals': 15.0},
#     {'player_name': 'Memphis', 'player_goals': 12.0},
#     {'player_name': 'Jordi Alba', 'player_goals': 11.0},
#     {'player_name': 'Pierre-Emerick Aubameyang', 'player_goals': 11.0},
#     {'player_name': 'Arturo Vidal', 'player_goals': 11.0},
#     {'player_name': 'Paulinho', 'player_goals': 9.0},
#     {'player_name': 'Gerard PiquÃ©', 'player_goals': 8.0},
#     {'player_name': 'Frenkie de Jong', 'player_goals': 8.0},
#     {'player_name': 'Pedri', 'player_goals': 6.0},
#     {'player_name': 'Luuk de Jong', 'player_goals': 6.0},
#     {'player_name': 'Ronald AraÃºjo', 'player_goals': 6.0},
#     {'player_name': 'Martin Braithwaite', 'player_goals': 5.0},
#     {'player_name': 'Sergio Busquets', 'player_goals': 5.0},
#     {'player_name': 'Sergi Roberto', 'player_goals': 5.0},
#     {'player_name': 'Ivan RakitiÄ‡', 'player_goals': 5.0},
#     {'player_name': 'FerrÃ¡n Torres', 'player_goals': 4.0},
#     {'player_name': 'ClÃ©ment Lenglet', 'player_goals': 4.0},
#     {'player_name': 'Paco AlcÃ¡cer', 'player_goals': 4.0},
#     {'player_name': 'Francisco TrincÃ£o', 'player_goals': 3.0},
#     {'player_name': 'Arthur Melo', 'player_goals': 3.0},
#     {'player_name': 'Junior Firpo', 'player_goals': 2.0},
#     {'player_name': 'NÃ©lson Semedo', 'player_goals': 2.0},
#     {'player_name': 'NicolÃ¡s GonzÃ¡lez', 'player_goals': 2.0},
#     {'player_name': 'Ã“scar Mingueza', 'player_goals': 2.0},
#     {'player_name': 'Carles AleÃ±Ã¡', 'player_goals': 2.0},
#     {'player_name': 'Riqui Puig', 'player_goals': 2.0},
#     {'player_name': 'Gavi', 'player_goals': 2.0},
#     {'player_name': 'Denis SuÃ¡rez', 'player_goals': 2.0},
#     {'player_name': 'SergiÃ±o Dest', 'player_goals': 2.0},
#     {'player_name': 'Samuel Umtiti', 'player_goals': 1.0},
#     {'player_name': 'Sergio AgÃ¼ero', 'player_goals': 1.0},
#     {'player_name': 'Munir El Haddadi', 'player_goals': 1.0},
#     {'player_name': 'Malcom', 'player_goals': 1.0},
#     {'player_name': 'JutglÃ', 'player_goals': 1.0},
#     {'player_name': 'Ilaix Moriba', 'player_goals': 1.0},
#     {'player_name': 'Gerard Deulofeu', 'player_goals': 1.0},
#     {'player_name': 'Dani Alves', 'player_goals': 1.0},
#     {'player_name': 'Carles PÃ©rez', 'player_goals': 1.0},
#     {'player_name': 'AndrÃ©s Iniesta', 'player_goals': 1.0},
#     {'player_name': 'Aleix Vidal', 'player_goals': 1.0},
#     {'player_name': 'Abdessamad Ezzalzouli', 'player_goals': 1.0}]},
#   {'squad_name': 'Real Madrid',
#    'squad_goals': 374.0,
#    'players': [{'player_name': 'Karim Benzema', 'player_goals': 97.0},
#     {'player_name': 'Gareth Bale', 'player_goals': 27.0},
#     {'player_name': 'Cristiano Ronaldo', 'player_goals': 26.0},
#     {'player_name': 'Vinicius JÃºnior', 'player_goals': 25.0},
#     {'player_name': 'Marco Asensio', 'player_goals': 25.0},
#     {'player_name': 'Sergio Ramos', 'player_goals': 23.0},
#     {'player_name': 'Casemiro', 'player_goals': 19.0},
#     {'player_name': 'Luka ModriÄ‡', 'player_goals': 14.0},
#     {'player_name': 'Toni Kroos', 'player_goals': 13.0},
#     {'player_name': 'Isco', 'player_goals': 12.0},
#     {'player_name': 'Lucas VÃ¡zquez', 'player_goals': 12.0},
#     {'player_name': 'Nacho', 'player_goals': 8.0},
#     {'player_name': 'Rodrygo', 'player_goals': 7.0},
#     {'player_name': 'RaphaÃ«l Varane', 'player_goals': 6.0},
#     {'player_name': 'Mariano', 'player_goals': 6.0},
#     {'player_name': 'Federico Valverde', 'player_goals': 5.0},
#     {'player_name': 'Marcelo', 'player_goals': 5.0},
#     {'player_name': 'Dani Ceballos', 'player_goals': 5.0},
#     {'player_name': 'Eden Hazard', 'player_goals': 4.0},
#     {'player_name': 'Ferland Mendy', 'player_goals': 4.0},
#     {'player_name': 'Borja Mayoral', 'player_goals': 3.0},
#     {'player_name': 'Luka JoviÄ‡', 'player_goals': 3.0},
#     {'player_name': 'Dani Carvajal', 'player_goals': 3.0},
#     {'player_name': 'Achraf Hakimi', 'player_goals': 2.0},
#     {'player_name': 'Ã‰der MilitÃ£o', 'player_goals': 2.0},
#     {'player_name': 'David Alaba', 'player_goals': 2.0},
#     {'player_name': 'Ã\x81lvaro Odriozola', 'player_goals': 2.0},
#     {'player_name': 'Eduardo Camavinga', 'player_goals': 2.0},
#     {'player_name': 'James RodrÃ\xadguez', 'player_goals': 1.0},
#     {'player_name': 'Brahim DÃ\xadaz', 'player_goals': 1.0},
#     {'player_name': 'JesÃºs Vallejo', 'player_goals': 1.0}]},
#   {'squad_name': 'AtlÃ©tico Madrid',
#    'squad_goals': 296.0,
#    'players': [{'player_name': 'Antoine Griezmann', 'player_goals': 37.0},
#     {'player_name': 'Ã\x81ngel Correa', 'player_goals': 37.0},
#     {'player_name': 'Luis SuÃ¡rez', 'player_goals': 32.0},
#     {'player_name': 'JoÃ£o FÃ©lix', 'player_goals': 21.0},
#     {'player_name': 'Ã\x81lvaro Morata', 'player_goals': 18.0},
#     {'player_name': 'Yannick Carrasco', 'player_goals': 16.0},
#     {'player_name': 'Marcos Llorente', 'player_goals': 15.0},
#     {'player_name': 'SaÃºl Ã‘Ã\xadguez', 'player_goals': 14.0},
#     {'player_name': 'Koke', 'player_goals': 13.0},
#     {'player_name': 'Diego Costa', 'player_goals': 12.0},
#     {'player_name': 'Thomas Partey', 'player_goals': 9.0},
#     {'player_name': 'Thomas Lemar', 'player_goals': 8.0},
#     {'player_name': 'KÃ©vin Gameiro', 'player_goals': 7.0},
#     {'player_name': 'Matheus Cunha', 'player_goals': 6.0},
#     {'player_name': 'Fernando Torres', 'player_goals': 5.0},
#     {'player_name': 'Vitolo', 'player_goals': 4.0},
#     {'player_name': 'Renan Lodi', 'player_goals': 4.0},
#     {'player_name': 'Diego GodÃ\xadn', 'player_goals': 3.0},
#     {'player_name': 'Rodri', 'player_goals': 3.0},
#     {'player_name': 'Filipe LuÃ\xads', 'player_goals': 3.0},
#     {'player_name': 'Felipe', 'player_goals': 3.0},
#     {'player_name': 'Mario Hermoso', 'player_goals': 3.0},
#     {'player_name': 'Rodrigo De Paul', 'player_goals': 3.0},
#     {'player_name': 'Nikola KaliniÄ‡', 'player_goals': 2.0},
#     {'player_name': 'JosÃ© MarÃ\xada GimÃ©nez', 'player_goals': 2.0},
#     {'player_name': 'Santiago Arias', 'player_goals': 1.0},
#     {'player_name': 'Sergio Camello', 'player_goals': 1.0},
#     {'player_name': 'Stefan SaviÄ‡', 'player_goals': 1.0},
#     {'player_name': 'Lucas Torreira', 'player_goals': 1.0},
#     {'player_name': 'Lucas HernÃ¡ndez', 'player_goals': 1.0},
#     {'player_name': 'Geoffrey Kondogbia', 'player_goals': 1.0},
#     {'player_name': 'Borja GarcÃ©s', 'player_goals': 1.0},
#     {'player_name': 'Å\xa0ime Vrsaljko', 'player_goals': 1.0}]},
#   {'squad_name': 'Villarreal',
#    'squad_goals': 292.0,
#    'players': [{'player_name': 'Gerard Moreno', 'player_goals': 58.0},
#     {'player_name': 'Carlos Bacca', 'player_goals': 28.0},
#     {'player_name': 'Karl Toko Ekambi', 'player_goals': 16.0},
#     {'player_name': 'Santi Cazorla', 'player_goals': 15.0},
#     {'player_name': 'Samuel Chukwueze', 'player_goals': 15.0},
#     {'player_name': 'Manu Trigueros', 'player_goals': 12.0},
#     {'player_name': 'Moi GÃ³mez', 'player_goals': 11.0},
#     {'player_name': 'Paco AlcÃ¡cer', 'player_goals': 11.0},
#     {'player_name': 'Arnaut Danjuma', 'player_goals': 10.0},
#     {'player_name': 'Yeremi Pino', 'player_goals': 9.0},
#     {'player_name': 'Pau Torres', 'player_goals': 9.0},
#     {'player_name': 'CÃ©dric Bakambu', 'player_goals': 9.0},
#     {'player_name': 'Alfonso Pedraza', 'player_goals': 8.0},
#     {'player_name': 'Nicola Sansone', 'player_goals': 6.0},
#     {'player_name': 'Samu Castillejo', 'player_goals': 6.0},
#     {'player_name': 'Pablo Fornals', 'player_goals': 5.0},
#     {'player_name': 'Enes Ãœnal', 'player_goals': 5.0},
#     {'player_name': 'Daniel Parejo', 'player_goals': 5.0},
#     {'player_name': 'Boulaye Dia', 'player_goals': 5.0},
#     {'player_name': 'Fernando NiÃ±o', 'player_goals': 4.0},
#     {'player_name': 'Vicente Iborra', 'player_goals': 4.0},
#     {'player_name': 'Alberto Moreno', 'player_goals': 3.0},
#     {'player_name': 'Mario Gaspar', 'player_goals': 3.0},
#     {'player_name': 'RubÃ©n PeÃ±a', 'player_goals': 3.0},
#     {'player_name': 'Andre-Frank Zambo Anguissa', 'player_goals': 2.0},
#     {'player_name': 'Ã‰tienne Capoue', 'player_goals': 2.0},
#     {'player_name': 'Dani Raba', 'player_goals': 2.0},
#     {'player_name': 'Javier Ontiveros', 'player_goals': 2.0},
#     {'player_name': 'Ramiro Funes Mori', 'player_goals': 2.0},
#     {'player_name': 'Francis Coquelin', 'player_goals': 2.0},
#     {'player_name': 'VÃ\xadctor Ruiz', 'player_goals': 2.0},
#     {'player_name': 'Denis Cheryshev', 'player_goals': 2.0},
#     {'player_name': 'Rodri', 'player_goals': 1.0},
#     {'player_name': 'Roger MartÃ\xadnez', 'player_goals': 1.0},
#     {'player_name': 'RaÃºl Albiol', 'player_goals': 1.0},
#     {'player_name': 'AÃ¯ssa Mandi', 'player_goals': 1.0},
#     {'player_name': 'Jaume Costa', 'player_goals': 1.0},
#     {'player_name': 'Ã\x81lvaro GonzÃ¡lez', 'player_goals': 1.0},
#     {'player_name': 'Giovani Lo Celso', 'player_goals': 1.0},
#     {'player_name': 'Juan Foyth', 'player_goals': 1.0}]},
#   {'squad_name': 'Sevilla',
#    'squad_goals': 271.0,
#    'players': [{'player_name': 'Youssef En-Nesyri', 'player_goals': 27.0},
#     {'player_name': 'Wissam Ben Yedder', 'player_goals': 27.0},
#     {'player_name': 'Lucas Ocampos', 'player_goals': 25.0},
#     {'player_name': 'Pablo Sarabia', 'player_goals': 18.0},
#     {'player_name': 'Munir El Haddadi', 'player_goals': 16.0},
#     {'player_name': 'Franco VÃ¡zquez', 'player_goals': 11.0},
#     {'player_name': 'Luuk de Jong', 'player_goals': 10.0},
#     {'player_name': 'Rafa Mir', 'player_goals': 10.0},
#     {'player_name': 'Ã‰ver Banega', 'player_goals': 9.0},
#     {'player_name': 'AndrÃ© Silva', 'player_goals': 9.0},
#     {'player_name': 'Ivan RakitiÄ‡', 'player_goals': 8.0},
#     {'player_name': 'Papu GÃ³mez', 'player_goals': 8.0},
#     {'player_name': 'Luis Muriel', 'player_goals': 8.0},
#     {'player_name': 'Nolito', 'player_goals': 7.0},
#     {'player_name': 'Fernando', 'player_goals': 6.0},
#     {'player_name': 'Diego Carlos', 'player_goals': 6.0},
#     {'player_name': 'Ã“liver Torres', 'player_goals': 5.0},
#     {'player_name': 'Ã‰rik Lamela', 'player_goals': 5.0},
#     {'player_name': 'Jules KoundÃ©', 'player_goals': 5.0},
#     {'player_name': 'Suso', 'player_goals': 4.0},
#     {'player_name': 'ClÃ©ment Lenglet', 'player_goals': 3.0},
#     {'player_name': 'Joan JordÃ¡n', 'player_goals': 3.0},
#     {'player_name': 'Ganso', 'player_goals': 2.0},
#     {'player_name': 'Gabriel Mercado', 'player_goals': 2.0},
#     {'player_name': 'JesÃºs Navas', 'player_goals': 2.0},
#     {'player_name': 'Roque Mesa', 'player_goals': 2.0},
#     {'player_name': 'Sergio Escudero', 'player_goals': 2.0},
#     {'player_name': 'Sergio ReguilÃ³n', 'player_goals': 2.0},
#     {'player_name': 'Simon KjÃ¦r', 'player_goals': 2.0},
#     {'player_name': 'Marcos AcuÃ±a', 'player_goals': 2.0},
#     {'player_name': 'Thomas Delaney', 'player_goals': 2.0},
#     {'player_name': 'JesÃºs Corona', 'player_goals': 2.0},
#     {'player_name': 'Quincy Promes', 'player_goals': 2.0},
#     {'player_name': 'Miguel LayÃºn', 'player_goals': 2.0},
#     {'player_name': 'Gonzalo Montiel', 'player_goals': 1.0},
#     {'player_name': 'Michael Krohn-Dehli', 'player_goals': 1.0},
#     {'player_name': 'JoaquÃ\xadn Correa', 'player_goals': 1.0},
#     {'player_name': 'Steven Nzonzi', 'player_goals': 1.0},
#     {'player_name': 'Javier HernÃ¡ndez', 'player_goals': 1.0},
#     {'player_name': 'Guido Pizarro', 'player_goals': 1.0},
#     {'player_name': 'Daniel CarriÃ§o', 'player_goals': 1.0},
#     {'player_name': 'Carlos FernÃ¡ndez', 'player_goals': 1.0},
#     {'player_name': 'Yassine Bounou', 'player_goals': 1.0},
#     {'player_name': 'Bryan', 'player_goals': 1.0}]},
#   {'squad_name': 'Real Sociedad',
#    'squad_goals': 266.0,
#    'players': [{'player_name': 'Mikel Oyarzabal', 'player_goals': 55.0},
#     {'player_name': 'Willian JosÃ©', 'player_goals': 40.0},
#     {'player_name': 'Alexander Isak', 'player_goals': 32.0},
#     {'player_name': 'Portu', 'player_goals': 16.0},
#     {'player_name': 'Adnan Januzaj', 'player_goals': 14.0},
#     {'player_name': 'Juanmi', 'player_goals': 13.0},
#     {'player_name': 'Mikel Merino', 'player_goals': 13.0},
#     {'player_name': 'Aritz Elustondo', 'player_goals': 9.0},
#     {'player_name': 'Asier Illarramendi', 'player_goals': 8.0},
#     {'player_name': 'Ander Barrenetxea', 'player_goals': 6.0},
#     {'player_name': 'Martin Ã˜degaard', 'player_goals': 4.0},
#     {'player_name': 'Alexander SÃ¸rloth', 'player_goals': 4.0},
#     {'player_name': 'David Silva', 'player_goals': 4.0},
#     {'player_name': 'Diego Llorente', 'player_goals': 4.0},
#     {'player_name': 'Sergio Canales', 'player_goals': 4.0},
#     {'player_name': 'Xabi Prieto', 'player_goals': 3.0},
#     {'player_name': 'Nacho Monreal', 'player_goals': 3.0},
#     {'player_name': 'Roberto LÃ³pez', 'player_goals': 3.0},
#     {'player_name': 'Julen Lobete', 'player_goals': 2.0},
#     {'player_name': 'Robin Le Normand', 'player_goals': 2.0},
#     {'player_name': 'David Zurutuza', 'player_goals': 2.0},
#     {'player_name': 'HÃ©ctor Moreno', 'player_goals': 2.0},
#     {'player_name': 'Igor Zubeldia', 'player_goals': 2.0},
#     {'player_name': 'MartÃ\xadn Zubimendi', 'player_goals': 2.0},
#     {'player_name': 'Jon Bautista', 'player_goals': 2.0},
#     {'player_name': 'RubÃ©n Pardo', 'player_goals': 1.0},
#     {'player_name': 'Jon Guridi', 'player_goals': 1.0},
#     {'player_name': 'Ander Guevara', 'player_goals': 1.0},
#     {'player_name': 'IÃ±igo MartÃ\xadnez', 'player_goals': 1.0},
#     {'player_name': 'Joseba ZaldÃºa', 'player_goals': 1.0},
#     {'player_name': 'Luca Sangalli', 'player_goals': 1.0},
#     {'player_name': 'Carlos FernÃ¡ndez', 'player_goals': 1.0},
#     {'player_name': 'Carlos Vela', 'player_goals': 1.0},
#     {'player_name': 'Theo HernÃ¡ndez', 'player_goals': 1.0},
#     {'player_name': 'Rafinha', 'player_goals': 1.0},
#     {'player_name': 'KÃ©vin Rodrigues', 'player_goals': 1.0}]},
#   {'squad_name': 'Betis',
#    'squad_goals': 264.0,
#    'players': [{'player_name': 'Sergio Canales', 'player_goals': 26.0},
#     {'player_name': 'Loren MorÃ³n', 'player_goals': 24.0},
#     {'player_name': 'Borja Iglesias', 'player_goals': 24.0},
#     {'player_name': 'JoaquÃ\xadn', 'player_goals': 20.0},
#     {'player_name': 'Juanmi', 'player_goals': 19.0},
#     {'player_name': 'Nabil Fekir', 'player_goals': 18.0},
#     {'player_name': 'Cristian Tello', 'player_goals': 17.0},
#     {'player_name': 'Antonio Sanabria', 'player_goals': 13.0},
#     {'player_name': 'Sergio LeÃ³n', 'player_goals': 11.0},
#     {'player_name': 'Giovani Lo Celso', 'player_goals': 9.0},
#     {'player_name': 'Willian JosÃ©', 'player_goals': 8.0},
#     {'player_name': 'Marc Bartra', 'player_goals': 6.0},
#     {'player_name': 'Zouhair Feddal', 'player_goals': 5.0},
#     {'player_name': 'Junior Firpo', 'player_goals': 5.0},
#     {'player_name': 'Ã\x81lex Moreno', 'player_goals': 5.0},
#     {'player_name': 'AÃ¯ssa Mandi', 'player_goals': 5.0},
#     {'player_name': 'William Carvalho', 'player_goals': 4.0},
#     {'player_name': 'Emerson', 'player_goals': 4.0},
#     {'player_name': 'Guido RodrÃ\xadguez', 'player_goals': 3.0},
#     {'player_name': 'FabiÃ¡n Ruiz PeÃ±a', 'player_goals': 3.0},
#     {'player_name': 'AndrÃ©s Guardado', 'player_goals': 3.0},
#     {'player_name': 'Sidnei', 'player_goals': 2.0},
#     {'player_name': 'Joel Campbell', 'player_goals': 2.0},
#     {'player_name': 'Aitor Ruibal', 'player_goals': 2.0},
#     {'player_name': 'JesÃ©', 'player_goals': 2.0},
#     {'player_name': 'Riza Durmisi', 'player_goals': 2.0},
#     {'player_name': 'Ryad Boudebouz', 'player_goals': 2.0},
#     {'player_name': 'VÃ\xadctor Ruiz', 'player_goals': 2.0},
#     {'player_name': 'GermÃ¡n Pezzella', 'player_goals': 1.0},
#     {'player_name': 'VÃ\xadctor Camarasa', 'player_goals': 1.0},
#     {'player_name': 'RubÃ©n Castro', 'player_goals': 1.0},
#     {'player_name': 'Rodrigo', 'player_goals': 1.0},
#     {'player_name': 'Kike Hermoso', 'player_goals': 1.0},
#     {'player_name': 'Juan Miranda', 'player_goals': 1.0},
#     {'player_name': 'Javi GarcÃ\xada', 'player_goals': 1.0},
#     {'player_name': 'Francis Guerrero', 'player_goals': 1.0},
#     {'player_name': 'Carles AleÃ±Ã¡', 'player_goals': 1.0},
#     {'player_name': 'Alfonso Pedraza', 'player_goals': 1.0},
#     {'player_name': 'Ã‰dgar GonzÃ¡lez', 'player_goals': 1.0}]},
#   {'squad_name': 'Valencia',
#    'squad_goals': 260.0,
#    'players': [{'player_name': 'Rodrigo', 'player_goals': 28.0},
#     {'player_name': 'GonÃ§alo Guedes', 'player_goals': 28.0},
#     {'player_name': 'Carlos Soler', 'player_goals': 27.0},
#     {'player_name': 'Daniel Parejo', 'player_goals': 24.0},
#     {'player_name': 'Maxi GÃ³mez', 'player_goals': 22.0},
#     {'player_name': 'Santi Mina', 'player_goals': 19.0},
#     {'player_name': 'KÃ©vin Gameiro', 'player_goals': 16.0},
#     {'player_name': 'Simone Zaza', 'player_goals': 13.0},
#     {'player_name': 'Hugo Duro', 'player_goals': 7.0},
#     {'player_name': 'Gabriel Paulista', 'player_goals': 7.0},
#     {'player_name': 'Daniel Wass', 'player_goals': 7.0},
#     {'player_name': 'Manu Vallejo', 'player_goals': 7.0},
#     {'player_name': 'FerrÃ¡n Torres', 'player_goals': 6.0},
#     {'player_name': 'Geoffrey Kondogbia', 'player_goals': 6.0},
#     {'player_name': 'JosÃ© Luis GayÃ', 'player_goals': 4.0},
#     {'player_name': 'Denis Cheryshev', 'player_goals': 3.0},
#     {'player_name': 'Mouctar Diakhaby', 'player_goals': 3.0},
#     {'player_name': 'Luciano Vietto', 'player_goals': 2.0},
#     {'player_name': 'Cristiano Piccini', 'player_goals': 2.0},
#     {'player_name': 'Omar Alderete', 'player_goals': 2.0},
#     {'player_name': 'Ezequiel Garay', 'player_goals': 2.0},
#     {'player_name': 'Yunus Musah', 'player_goals': 2.0},
#     {'player_name': 'Hugo GuillamÃ³n', 'player_goals': 2.0},
#     {'player_name': 'Lee Kangin', 'player_goals': 2.0},
#     {'player_name': 'Andreas Pereira', 'player_goals': 1.0},
#     {'player_name': 'Francis Coquelin', 'player_goals': 1.0},
#     {'player_name': 'RubÃ©n Sobrino', 'player_goals': 1.0},
#     {'player_name': 'MaranhÃ£o', 'player_goals': 1.0},
#     {'player_name': 'Michy Batshuayi', 'player_goals': 1.0},
#     {'player_name': 'Thierry Correia', 'player_goals': 1.0},
#     {'player_name': 'Nacho Vidal', 'player_goals': 1.0},
#     {'player_name': 'UroÅ¡ RaÄ\x8diÄ‡', 'player_goals': 1.0},
#     {'player_name': 'Toni Lato', 'player_goals': 1.0},
#     {'player_name': 'Alejandro Blanco', 'player_goals': 1.0}]},
#   {'squad_name': 'Celta Vigo',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Iago Aspas', 'player_goals': 88.0}]},
#   {'squad_name': 'Levante',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'JosÃ© Luis Morales', 'player_goals': 52.0},
#     {'player_name': 'Roger MartÃ\xad', 'player_goals': 46.0}]},
#   {'squad_name': 'Celta Vigo',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Maxi GÃ³mez', 'player_goals': 30.0},
#     {'player_name': 'Santi Mina', 'player_goals': 25.0}]},
#   {'squad_name': 'Levante',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Enis Bardhi', 'player_goals': 23.0}]},
#   {'squad_name': 'Celta Vigo',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Brais MÃ©ndez', 'player_goals': 20.0}]},
#   {'squad_name': 'Levante',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Gonzalo Melero', 'player_goals': 16.0},
#     {'player_name': 'Borja Mayoral', 'player_goals': 11.0}]},
#   {'squad_name': 'Celta Vigo',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Nolito', 'player_goals': 11.0}]},
#   {'squad_name': 'Levante',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'JosÃ© CampaÃ±a', 'player_goals': 10.0},
#     {'player_name': 'Coke', 'player_goals': 9.0},
#     {'player_name': 'RubÃ©n Rochina', 'player_goals': 9.0}]},
#   {'squad_name': 'Celta Vigo',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Pione Sisto', 'player_goals': 9.0}]},
#   {'squad_name': 'Levante',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Jorge de Frutos', 'player_goals': 8.0},
#     {'player_name': 'Emmanuel Boateng', 'player_goals': 7.0}]},
#   {'squad_name': 'Celta Vigo',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Fran BeltrÃ¡n', 'player_goals': 6.0}]},
#   {'squad_name': 'Levante',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Dani GÃ³mez', 'player_goals': 6.0}]},
#   {'squad_name': 'Celta Vigo',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Denis SuÃ¡rez', 'player_goals': 5.0},
#     {'player_name': 'Hugo Mallo', 'player_goals': 5.0},
#     {'player_name': 'Franco Cervi', 'player_goals': 4.0}]},
#   {'squad_name': 'Levante',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Ivi', 'player_goals': 4.0}]},
#   {'squad_name': 'Celta Vigo',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Rafinha', 'player_goals': 4.0},
#     {'player_name': 'NÃ©stor Araujo', 'player_goals': 4.0}]},
#   {'squad_name': 'Levante',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'RÃºben Vezo', 'player_goals': 4.0}]},
#   {'squad_name': 'Celta Vigo',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Daniel Wass', 'player_goals': 4.0},
#     {'player_name': 'Sofiane Boufal', 'player_goals': 3.0}]},
#   {'squad_name': 'Levante',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Chema', 'player_goals': 3.0},
#     {'player_name': 'Ã“scar Duarte', 'player_goals': 3.0},
#     {'player_name': 'Jason', 'player_goals': 3.0},
#     {'player_name': 'Roberto Soldado', 'player_goals': 3.0},
#     {'player_name': 'Sergio LeÃ³n', 'player_goals': 3.0},
#     {'player_name': 'Sergio Postigo', 'player_goals': 3.0}]},
#   {'squad_name': 'Celta Vigo',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Jeison Murillo', 'player_goals': 3.0},
#     {'player_name': 'Pablo HernÃ¡ndez', 'player_goals': 3.0}]},
#   {'squad_name': 'Levante',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Rober', 'player_goals': 2.0},
#     {'player_name': 'Erick Cabaco', 'player_goals': 2.0}]},
#   {'squad_name': 'Celta Vigo',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Jonny Castro', 'player_goals': 2.0}]},
#   {'squad_name': 'Levante',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Mickael Malsa', 'player_goals': 2.0}]},
#   {'squad_name': 'Celta Vigo',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Okay YokuÅŸlu', 'player_goals': 2.0},
#     {'player_name': 'Thiago Galhardo', 'player_goals': 2.0}]},
#   {'squad_name': 'Levante',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'HernÃ¢ni Fortes', 'player_goals': 2.0}]},
#   {'squad_name': 'Celta Vigo',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Augusto Solari', 'player_goals': 2.0},
#     {'player_name': 'Fyodor Smolov', 'player_goals': 2.0}]},
#   {'squad_name': 'Levante',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Cheick DoukourÃ©', 'player_goals': 1.0}]},
#   {'squad_name': 'Celta Vigo',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'Sergio Carreira', 'player_goals': 1.0},
#     {'player_name': 'Sergi GÃ³mez', 'player_goals': 1.0},
#     {'player_name': 'Ryad Boudebouz', 'player_goals': 1.0},
#     {'player_name': 'Miguel Baeza', 'player_goals': 1.0},
#     {'player_name': 'Lucas Olaza', 'player_goals': 1.0},
#     {'player_name': 'Losada', 'player_goals': 1.0},
#     {'player_name': 'Gustavo Cabral', 'player_goals': 1.0},
#     {'player_name': 'Gabriel FernÃ¡ndez', 'player_goals': 1.0},
#     {'player_name': 'Facundo Ferreyra', 'player_goals': 1.0},
#     {'player_name': 'Emre Mor', 'player_goals': 1.0}]},
#   {'squad_name': 'Levante',
#    'squad_goals': 247.0,
#    'players': [{'player_name': 'ToÃ±o', 'player_goals': 1.0},
#     {'player_name': 'Son', 'player_goals': 1.0},
#     {'player_name': 'Shkodran Mustafi', 'player_goals': 1.0},
#     {'player_name': 'Nemanja Radoja', 'player_goals': 1.0},
#     {'player_name': 'Moses Simon', 'player_goals': 1.0},
#     {'player_name': 'Jorge MiramÃ³n', 'player_goals': 1.0},
#     {'player_name': 'Giampaolo Pazzini', 'player_goals': 1.0},
#     {'player_name': 'Enes Ãœnal', 'player_goals': 1.0}]},
#   {'squad_name': 'Athletic Club',
#    'squad_goals': 212.0,
#    'players': [{'player_name': 'RaÃºl GarcÃ\xada', 'player_goals': 45.0},
#     {'player_name': 'IÃ±aki Williams', 'player_goals': 40.0},
#     {'player_name': 'Iker Muniain', 'player_goals': 25.0},
#     {'player_name': 'Aritz Aduriz', 'player_goals': 12.0},
#     {'player_name': 'Ã\x81lex Berenguer', 'player_goals': 11.0},
#     {'player_name': 'Oihan Sancet', 'player_goals': 9.0},
#     {'player_name': 'Asier Villalibre', 'player_goals': 9.0},
#     {'player_name': 'Yuri Berchiche', 'player_goals': 6.0},
#     {'player_name': 'IÃ±igo MartÃ\xadnez', 'player_goals': 5.0},
#     {'player_name': 'Ander Capa', 'player_goals': 5.0},
#     {'player_name': 'Unai LÃ³pez', 'player_goals': 4.0},
#     {'player_name': 'Ã“scar de Marcos', 'player_goals': 4.0},
#     {'player_name': 'Markel Susaeta', 'player_goals': 4.0},
#     {'player_name': 'Mikel Vesga', 'player_goals': 3.0},
#     {'player_name': 'Kenan Kodro', 'player_goals': 3.0},
#     {'player_name': 'Unai NÃºÃ±ez', 'player_goals': 2.0},
#     {'player_name': 'Jon Morcillo', 'player_goals': 2.0},
#     {'player_name': 'Daniel Vivian', 'player_goals': 2.0},
#     {'player_name': 'IÃ±igo CÃ³rdoba', 'player_goals': 2.0},
#     {'player_name': 'Peru Nolaskoain', 'player_goals': 2.0},
#     {'player_name': 'Oier Zarraga', 'player_goals': 1.0},
#     {'player_name': 'Yeray Ã\x81lvarez', 'player_goals': 1.0},
#     {'player_name': 'Xabier Etxeita', 'player_goals': 1.0},
#     {'player_name': 'NicolÃ¡s Serrano', 'player_goals': 1.0},
#     {'player_name': 'Mikel San JosÃ©', 'player_goals': 1.0},
#     {'player_name': 'BeÃ±at Etxebarria', 'player_goals': 1.0}]},
#   {'squad_name': 'Getafe',
#    'squad_goals': 194.0,
#    'players': [{'player_name': 'Ã\x81ngel RodrÃ\xadguez',
#      'player_goals': 36.0},
#     {'player_name': 'Jaime Mata', 'player_goals': 31.0},
#     {'player_name': 'Jorge Molina', 'player_goals': 26.0},
#     {'player_name': 'Enes Ãœnal', 'player_goals': 20.0},
#     {'player_name': 'Borja Mayoral', 'player_goals': 6.0},
#     {'player_name': 'Mauro Arambarri', 'player_goals': 6.0},
#     {'player_name': 'Nemanja MaksimoviÄ‡', 'player_goals': 5.0},
#     {'player_name': 'Amath', 'player_goals': 4.0},
#     {'player_name': 'Marc Cucurella', 'player_goals': 4.0},
#     {'player_name': 'Leandro Cabrera', 'player_goals': 4.0},
#     {'player_name': 'Markel Bergara', 'player_goals': 4.0},
#     {'player_name': 'David Timor', 'player_goals': 3.0},
#     {'player_name': 'LoÃ¯c RÃ©my', 'player_goals': 3.0},
#     {'player_name': 'DamiÃ¡n SuÃ¡rez', 'player_goals': 3.0},
#     {'player_name': 'Francisco Portillo', 'player_goals': 3.0},
#     {'player_name': 'Carles AleÃ±Ã¡', 'player_goals': 3.0},
#     {'player_name': 'Sandro RamÃ\xadrez', 'player_goals': 3.0},
#     {'player_name': 'Dimitri Foulquier', 'player_goals': 3.0},
#     {'player_name': 'Cala', 'player_goals': 2.0},
#     {'player_name': 'Cucho', 'player_goals': 2.0},
#     {'player_name': 'MathÃ\xadas Olivera', 'player_goals': 2.0},
#     {'player_name': 'Allan Nyom', 'player_goals': 2.0},
#     {'player_name': 'FayÃ§al Fajr', 'player_goals': 1.0},
#     {'player_name': 'DarÃ\xado Poveda', 'player_goals': 1.0},
#     {'player_name': 'Kenedy', 'player_goals': 1.0},
#     {'player_name': 'Ã\x81lvaro JimÃ©nez', 'player_goals': 1.0},
#     {'player_name': 'Jason', 'player_goals': 1.0},
#     {'player_name': 'Hugo Duro', 'player_goals': 1.0},
#     {'player_name': 'Gaku Shibasaki', 'player_goals': 1.0},
#     {'player_name': 'Jorge Cuenca', 'player_goals': 1.0},
#     {'player_name': 'Vitorino Antunes', 'player_goals': 1.0},
#     {'player_name': 'Takefusa Kubo', 'player_goals': 1.0},
#     {'player_name': 'Samuel SÃ¡iz', 'player_goals': 1.0},
#     {'player_name': 'Oghenekaro Etebo', 'player_goals': 1.0},
#     {'player_name': 'DjenÃ©', 'player_goals': 1.0}]},
#   {'squad_name': 'AlavÃ©s',
#    'squad_goals': 180.0,
#    'players': [{'player_name': 'Joselu', 'player_goals': 36.0},
#     {'player_name': 'Lucas PÃ©rez', 'player_goals': 15.0},
#     {'player_name': 'Ibai GÃ³mez', 'player_goals': 10.0},
#     {'player_name': 'Munir El Haddadi', 'player_goals': 10.0},
#     {'player_name': 'Jonathan Calleri', 'player_goals': 9.0},
#     {'player_name': 'Ã‰dgar MÃ©ndez', 'player_goals': 7.0},
#     {'player_name': 'VÃ\xadctor Laguardia', 'player_goals': 7.0},
#     {'player_name': 'John Guidetti', 'player_goals': 6.0},
#     {'player_name': 'RubÃ©n Sobrino', 'player_goals': 6.0},
#     {'player_name': 'TomÃ¡s Pina Isla', 'player_goals': 5.0},
#     {'player_name': 'Gonzalo Escalante', 'player_goals': 5.0},
#     {'player_name': 'Luis Rioja', 'player_goals': 5.0},
#     {'player_name': 'Borja BastÃ³n', 'player_goals': 5.0},
#     {'player_name': 'Jony', 'player_goals': 5.0},
#     {'player_name': 'Manu GarcÃ\xada', 'player_goals': 4.0},
#     {'player_name': 'Pere Pons', 'player_goals': 4.0},
#     {'player_name': 'Rodrigo Ely', 'player_goals': 4.0},
#     {'player_name': 'Ximo Navarro', 'player_goals': 3.0},
#     {'player_name': 'Alfonso Pedraza', 'player_goals': 3.0},
#     {'player_name': 'Borja Sainz', 'player_goals': 2.0},
#     {'player_name': 'Guillermo MaripÃ¡n', 'player_goals': 2.0},
#     {'player_name': 'Christian Santos', 'player_goals': 2.0},
#     {'player_name': 'Aleix Vidal', 'player_goals': 2.0},
#     {'player_name': 'Mamadou Loum', 'player_goals': 2.0},
#     {'player_name': 'Takashi Inui', 'player_goals': 2.0},
#     {'player_name': 'Burgui', 'player_goals': 2.0},
#     {'player_name': 'Ã\x81lvaro MedrÃ¡n', 'player_goals': 2.0},
#     {'player_name': 'Alexis', 'player_goals': 1.0},
#     {'player_name': 'Deyverson', 'player_goals': 1.0},
#     {'player_name': 'Ermedin DemiroviÄ‡', 'player_goals': 1.0},
#     {'player_name': 'Florian Lejeune', 'player_goals': 1.0},
#     {'player_name': 'Lisandro MagallÃ¡n', 'player_goals': 1.0},
#     {'player_name': 'Manu Vallejo', 'player_goals': 1.0},
#     {'player_name': 'Martin Agirregabiria', 'player_goals': 1.0},
#     {'player_name': 'Miguel', 'player_goals': 1.0},
#     {'player_name': 'Oliver Burke', 'player_goals': 1.0},
#     {'player_name': 'Rodrigo Battaglia', 'player_goals': 1.0},
#     {'player_name': 'RubÃ©n Duarte', 'player_goals': 1.0},
#     {'player_name': 'Wakaso', 'player_goals': 1.0}]},
#   {'squad_name': 'Eibar',
#    'squad_goals': 158.0,
#    'players': [{'player_name': 'Kike', 'player_goals': 28.0},
#     {'player_name': 'Charles', 'player_goals': 28.0},
#     {'player_name': 'Sergi Enrich', 'player_goals': 14.0},
#     {'player_name': 'FabiÃ¡n Orellana', 'player_goals': 14.0},
#     {'player_name': 'Joan JordÃ¡n', 'player_goals': 10.0},
#     {'player_name': 'Takashi Inui', 'player_goals': 8.0},
#     {'player_name': 'Gonzalo Escalante', 'player_goals': 5.0},
#     {'player_name': 'Esteban Burgos', 'player_goals': 4.0},
#     {'player_name': 'Anaitz Arbilla', 'player_goals': 4.0},
#     {'player_name': 'IvÃ¡n Ramis', 'player_goals': 4.0},
#     {'player_name': 'Pablo de Blasis', 'player_goals': 4.0},
#     {'player_name': 'Bryan', 'player_goals': 4.0},
#     {'player_name': 'Edu ExpÃ³sito', 'player_goals': 4.0},
#     {'player_name': 'Pedro LeÃ³n', 'player_goals': 3.0},
#     {'player_name': 'Marc Cardona', 'player_goals': 3.0},
#     {'player_name': 'Pedro Bigas', 'player_goals': 3.0},
#     {'player_name': 'Papakouli Diop', 'player_goals': 3.0},
#     {'player_name': 'JosÃ© Ã\x81ngel', 'player_goals': 2.0},
#     {'player_name': 'RubÃ©n PeÃ±a', 'player_goals': 2.0},
#     {'player_name': 'IvÃ¡n Alejo', 'player_goals': 1.0},
#     {'player_name': 'Ã\x81lex GÃ¡lvez', 'player_goals': 1.0},
#     {'player_name': 'David LombÃ¡n', 'player_goals': 1.0},
#     {'player_name': 'KÃ©vin Rodrigues', 'player_goals': 1.0},
#     {'player_name': 'Marc Cucurella', 'player_goals': 1.0},
#     {'player_name': 'Marko DmitroviÄ‡', 'player_goals': 1.0},
#     {'player_name': 'Paulo Oliveira', 'player_goals': 1.0},
#     {'player_name': 'Recio', 'player_goals': 1.0},
#     {'player_name': 'Yoshinori MutÅ\x8d', 'player_goals': 1.0}]},
#   {'squad_name': 'Espanyol',
#    'squad_goals': 151.0,
#    'players': [{'player_name': 'RaÃºl de TomÃ¡s', 'player_goals': 21.0},
#     {'player_name': 'Borja Iglesias', 'player_goals': 17.0},
#     {'player_name': 'Gerard Moreno', 'player_goals': 16.0},
#     {'player_name': 'Sergi Darder', 'player_goals': 10.0},
#     {'player_name': 'LÃ©o BaptistÃ£o', 'player_goals': 10.0},
#     {'player_name': 'Wu Lei', 'player_goals': 8.0},
#     {'player_name': 'Esteban Granero', 'player_goals': 5.0},
#     {'player_name': 'David LÃ³pez', 'player_goals': 5.0},
#     {'player_name': 'Mario Hermoso', 'player_goals': 4.0},
#     {'player_name': 'Sergio GarcÃ\xada', 'player_goals': 4.0},
#     {'player_name': 'Javi Puado', 'player_goals': 4.0},
#     {'player_name': 'Marc Roca', 'player_goals': 3.0},
#     {'player_name': 'Pedrosa', 'player_goals': 3.0},
#     {'player_name': 'Bernardo Espinosa', 'player_goals': 3.0},
#     {'player_name': 'Roberto Rosales', 'player_goals': 3.0},
#     {'player_name': 'Pablo Piatti', 'player_goals': 3.0},
#     {'player_name': 'Nico Ribaudo', 'player_goals': 2.0},
#     {'player_name': 'Facundo Ferreyra', 'player_goals': 2.0},
#     {'player_name': 'Adri Embarba', 'player_goals': 2.0},
#     {'player_name': 'Aleix Vidal', 'player_goals': 2.0},
#     {'player_name': 'Leandro Cabrera', 'player_goals': 2.0},
#     {'player_name': 'Manu Morlanes', 'player_goals': 2.0},
#     {'player_name': 'Keidi Bare', 'player_goals': 1.0},
#     {'player_name': 'HernÃ¡n PÃ©rez', 'player_goals': 1.0},
#     {'player_name': 'Jonathan Calleri', 'player_goals': 1.0},
#     {'player_name': 'Loren MorÃ³n', 'player_goals': 1.0},
#     {'player_name': 'Marc Navarro', 'player_goals': 1.0},
#     {'player_name': 'Naldo', 'player_goals': 1.0},
#     {'player_name': 'Sergi GÃ³mez', 'player_goals': 1.0},
#     {'player_name': 'Tonny Vilhena', 'player_goals': 1.0},
#     {'player_name': 'Yangel Herrera', 'player_goals': 1.0}]},
#   {'squad_name': 'Granada',
#    'squad_goals': 143.0,
#    'players': [{'player_name': 'Jorge Molina', 'player_goals': 18.0},
#     {'player_name': 'Darwin MachÃ\xads', 'player_goals': 16.0},
#     {'player_name': 'Antonio Puertas', 'player_goals': 16.0},
#     {'player_name': 'Roberto Soldado', 'player_goals': 16.0},
#     {'player_name': 'Luis Javier SuÃ¡rez', 'player_goals': 13.0},
#     {'player_name': 'Carlos FernÃ¡ndez', 'player_goals': 10.0},
#     {'player_name': 'GermÃ¡n SÃ¡nchez', 'player_goals': 7.0},
#     {'player_name': 'Domingos Duarte', 'player_goals': 5.0},
#     {'player_name': 'Yangel Herrera', 'player_goals': 5.0},
#     {'player_name': 'Kenedy', 'player_goals': 4.0},
#     {'player_name': 'Ã\x81ngel Montoro', 'player_goals': 4.0},
#     {'player_name': 'Luis Milla', 'player_goals': 4.0},
#     {'player_name': 'Ã\x81lvaro Vadillo', 'player_goals': 3.0},
#     {'player_name': 'VÃ\xadctor DÃ\xadaz', 'player_goals': 2.0},
#     {'player_name': 'Ã\x81lex Collado', 'player_goals': 2.0},
#     {'player_name': 'Domingos Quina', 'player_goals': 2.0},
#     {'player_name': 'Fede Vico', 'player_goals': 2.0},
#     {'player_name': 'Ramon Azeez', 'player_goals': 2.0},
#     {'player_name': 'Sergio Escudero', 'player_goals': 2.0},
#     {'player_name': 'Antonio CortÃ©s', 'player_goals': 1.0},
#     {'player_name': 'Santiago Arias', 'player_goals': 1.0},
#     {'player_name': 'RubÃ©n Rochina', 'player_goals': 1.0},
#     {'player_name': 'Quini', 'player_goals': 1.0},
#     {'player_name': 'Myrto Uzuni', 'player_goals': 1.0},
#     {'player_name': 'Dimitri Foulquier', 'player_goals': 1.0},
#     {'player_name': 'Alberto Soro', 'player_goals': 1.0}]},
#   {'squad_name': 'Osasuna',
#    'squad_goals': 120.0,
#    'players': [{'player_name': 'Ante Budimir', 'player_goals': 19.0},
#     {'player_name': 'Roberto Torres', 'player_goals': 16.0},
#     {'player_name': 'Ezequiel Ã\x81vila', 'player_goals': 15.0},
#     {'player_name': 'RubÃ©n GarcÃ\xada', 'player_goals': 12.0},
#     {'player_name': 'Kike', 'player_goals': 5.0},
#     {'player_name': 'Jonathan Calleri', 'player_goals': 5.0},
#     {'player_name': 'Jon Moncayola', 'player_goals': 5.0},
#     {'player_name': 'David GarcÃ\xada', 'player_goals': 5.0},
#     {'player_name': 'Kike Barja', 'player_goals': 4.0},
#     {'player_name': 'Enric Gallego', 'player_goals': 3.0},
#     {'player_name': 'AdriÃ¡n LÃ³pez', 'player_goals': 3.0},
#     {'player_name': 'Aridane HernÃ¡ndez', 'player_goals': 3.0},
#     {'player_name': 'Darko BraÅ¡anac', 'player_goals': 3.0},
#     {'player_name': 'Oier Sanjurjo', 'player_goals': 3.0},
#     {'player_name': 'IÃ±igo PÃ©rez', 'player_goals': 3.0},
#     {'player_name': 'Facundo Roncaglia', 'player_goals': 2.0},
#     {'player_name': 'Javi MartÃ\xadnez', 'player_goals': 2.0},
#     {'player_name': 'JosÃ© Arnaiz', 'player_goals': 2.0},
#     {'player_name': 'Manuel SÃ¡nchez', 'player_goals': 1.0},
#     {'player_name': 'Toni Lato', 'player_goals': 1.0},
#     {'player_name': 'Robert IbÃ¡Ã±ez', 'player_goals': 1.0},
#     {'player_name': 'Pervis EstupiÃ±Ã¡n', 'player_goals': 1.0},
#     {'player_name': 'Unai GarcÃ\xada', 'player_goals': 1.0},
#     {'player_name': 'JosÃ© Ã\x81ngel', 'player_goals': 1.0},
#     {'player_name': 'Juan Villar', 'player_goals': 1.0},
#     {'player_name': 'Lucas TorrÃ³', 'player_goals': 1.0},
#     {'player_name': 'Marc Cardona', 'player_goals': 1.0}]},
#   {'squad_name': 'Valladolid',
#    'squad_goals': 98.0,
#    'players': [{'player_name': 'Ã“scar Plano', 'player_goals': 12.0},
#     {'player_name': 'Enes Ãœnal', 'player_goals': 12.0},
#     {'player_name': 'Sergi Guardiola', 'player_goals': 12.0},
#     {'player_name': 'RubÃ©n Alcaraz', 'player_goals': 6.0},
#     {'player_name': 'FabiÃ¡n Orellana', 'player_goals': 6.0},
#     {'player_name': 'Shon Weissman', 'player_goals': 6.0},
#     {'player_name': 'JoaquÃ\xadn FernÃ¡ndez', 'player_goals': 4.0},
#     {'player_name': 'MaranhÃ£o', 'player_goals': 4.0},
#     {'player_name': 'Toni Villa', 'player_goals': 4.0},
#     {'player_name': 'MÃ\xadchel', 'player_goals': 4.0},
#     {'player_name': 'Sandro RamÃ\xadrez', 'player_goals': 3.0},
#     {'player_name': 'Kiko Olivas', 'player_goals': 2.0},
#     {'player_name': 'AntoÃ±ito', 'player_goals': 2.0},
#     {'player_name': 'Daniele Verde', 'player_goals': 2.0},
#     {'player_name': 'Keko', 'player_goals': 2.0},
#     {'player_name': 'Leonardo SuÃ¡rez', 'player_goals': 2.0},
#     {'player_name': 'Waldo Rubio', 'player_goals': 2.0},
#     {'player_name': 'RaÃºl GarcÃ\xada', 'player_goals': 1.0},
#     {'player_name': 'Nacho', 'player_goals': 1.0},
#     {'player_name': 'Pablo HervÃ\xadas', 'player_goals': 1.0},
#     {'player_name': 'Roque Mesa', 'player_goals': 1.0},
#     {'player_name': 'Anuar', 'player_goals': 1.0},
#     {'player_name': 'Bruno GonzÃ¡lez', 'player_goals': 1.0},
#     {'player_name': 'Fernando Calero', 'player_goals': 1.0},
#     {'player_name': 'Jota', 'player_goals': 1.0},
#     {'player_name': 'VÃ\xadctor GarcÃ\xada', 'player_goals': 1.0},
#     {'player_name': 'Lucas Olaza', 'player_goals': 1.0},
#     {'player_name': 'Mohammed Salisu', 'player_goals': 1.0}]},
#   {'squad_name': 'Girona',
#    'squad_goals': 87.0,
#    'players': [{'player_name': 'Cristhian Stuani', 'player_goals': 40.0},
#     {'player_name': 'Portu', 'player_goals': 20.0},
#     {'player_name': 'Juanpe', 'player_goals': 5.0},
#     {'player_name': 'Michael Olunga', 'player_goals': 3.0},
#     {'player_name': 'Aleix GarcÃ\xada', 'player_goals': 3.0},
#     {'player_name': 'Borja GarcÃ\xada', 'player_goals': 3.0},
#     {'player_name': 'Seydou Doumbia', 'player_goals': 2.0},
#     {'player_name': 'Aday', 'player_goals': 2.0},
#     {'player_name': 'David Timor', 'player_goals': 2.0},
#     {'player_name': 'Pedro AlcalÃ¡', 'player_goals': 2.0},
#     {'player_name': 'Pere Pons', 'player_goals': 1.0},
#     {'player_name': 'Bernardo Espinosa', 'player_goals': 1.0},
#     {'player_name': 'Anthony Lozano', 'player_goals': 1.0},
#     {'player_name': 'JonÃ¡s Ramalho', 'player_goals': 1.0},
#     {'player_name': 'Ã\x81lex Granell', 'player_goals': 1.0}]},
#   {'squad_name': 'Rayo Vallecano',
#    'squad_goals': 80.0,
#    'players': [{'player_name': 'RaÃºl de TomÃ¡s', 'player_goals': 14.0},
#     {'player_name': 'Ã\x81lvaro GarcÃ\xada', 'player_goals': 11.0},
#     {'player_name': 'Sergi Guardiola', 'player_goals': 8.0},
#     {'player_name': 'Radamel Falcao', 'player_goals': 6.0},
#     {'player_name': 'Adri Embarba', 'player_goals': 5.0},
#     {'player_name': 'Ã“scar Trejo', 'player_goals': 4.0},
#     {'player_name': 'Randy Ntekja', 'player_goals': 3.0},
#     {'player_name': 'JosÃ© Pozo', 'player_goals': 3.0},
#     {'player_name': 'Ã\x81lvaro MedrÃ¡n', 'player_goals': 3.0},
#     {'player_name': 'Mario SuÃ¡rez', 'player_goals': 2.0},
#     {'player_name': 'Catena', 'player_goals': 2.0},
#     {'player_name': 'Santi ComesaÃ±a', 'player_goals': 2.0},
#     {'player_name': 'Isaac PalazÃ³n Camacho', 'player_goals': 2.0},
#     {'player_name': 'PathÃ© Ciss', 'player_goals': 2.0},
#     {'player_name': 'BebÃ©', 'player_goals': 2.0},
#     {'player_name': 'Ã\x81lex Moreno', 'player_goals': 1.0},
#     {'player_name': 'Francisco Garcia', 'player_goals': 1.0},
#     {'player_name': 'GaÃ«l Kakuta', 'player_goals': 1.0},
#     {'player_name': 'Giannelli Imbula', 'player_goals': 1.0},
#     {'player_name': 'Abdoulaye Ba', 'player_goals': 1.0},
#     {'player_name': 'IvÃ¡n Balliu', 'player_goals': 1.0},
#     {'player_name': 'Luis AdvÃ\xadncula', 'player_goals': 1.0},
#     {'player_name': 'Mario HernÃ¡ndez', 'player_goals': 1.0},
#     {'player_name': 'Ã\x81lex GÃ¡lvez', 'player_goals': 1.0}]},
#   {'squad_name': 'Huesca',
#    'squad_goals': 77.0,
#    'players': [{'player_name': 'Rafa Mir', 'player_goals': 13.0},
#     {'player_name': 'Ezequiel Ã\x81vila', 'player_goals': 10.0},
#     {'player_name': 'Sandro RamÃ\xadrez', 'player_goals': 5.0},
#     {'player_name': 'Enric Gallego', 'player_goals': 5.0},
#     {'player_name': 'Ã\x81lex Gallar', 'player_goals': 4.0},
#     {'player_name': 'Jorge Pulido', 'player_goals': 4.0},
#     {'player_name': 'Xabier Etxeita', 'player_goals': 4.0},
#     {'player_name': 'Cucho', 'player_goals': 4.0},
#     {'player_name': 'David Ferreiro', 'player_goals': 3.0},
#     {'player_name': 'Gonzalo Melero', 'player_goals': 2.0},
#     {'player_name': 'MartÃ\xadn Mantovani', 'player_goals': 2.0},
#     {'player_name': 'Juanpi', 'player_goals': 2.0},
#     {'player_name': 'Cristian Rivera', 'player_goals': 2.0},
#     {'player_name': 'Moi GÃ³mez', 'player_goals': 2.0},
#     {'player_name': 'Javier Ontiveros', 'player_goals': 2.0},
#     {'player_name': 'Dimitris Siovas', 'player_goals': 2.0},
#     {'player_name': 'Mikel Rico', 'player_goals': 1.0},
#     {'player_name': 'Jaime Seoane', 'player_goals': 1.0},
#     {'player_name': 'Dani Escriche', 'player_goals': 1.0},
#     {'player_name': 'Javi GalÃ¡n', 'player_goals': 1.0},
#     {'player_name': 'Jorge MiramÃ³n', 'player_goals': 1.0},
#     {'player_name': 'Borja GarcÃ\xada', 'player_goals': 1.0},
#     {'player_name': 'Shinji Okazaki', 'player_goals': 1.0},
#     {'player_name': 'Samuele Longo', 'player_goals': 1.0},
#     {'player_name': 'Pablo Maffeo', 'player_goals': 1.0}]},
#   {'squad_name': 'Mallorca',
#    'squad_goals': 76.0,
#    'players': [{'player_name': 'Ante Budimir', 'player_goals': 13.0},
#     {'player_name': 'Salva Sevilla', 'player_goals': 10.0},
#     {'player_name': 'Dani RodrÃ\xadguez', 'player_goals': 8.0},
#     {'player_name': 'Cucho', 'player_goals': 5.0},
#     {'player_name': 'Takefusa Kubo', 'player_goals': 5.0},
#     {'player_name': 'Vedat Muriqi', 'player_goals': 5.0},
#     {'player_name': 'Lago Junior', 'player_goals': 4.0},
#     {'player_name': 'Ã\x81ngel RodrÃ\xadguez', 'player_goals': 4.0},
#     {'player_name': 'Antonio Raillo', 'player_goals': 3.0},
#     {'player_name': 'AbdÃ³n Prats', 'player_goals': 3.0},
#     {'player_name': 'Fernando NiÃ±o', 'player_goals': 2.0},
#     {'player_name': 'Brian OlivÃ¡n', 'player_goals': 1.0},
#     {'player_name': 'Lumor Agbenyenu', 'player_goals': 1.0},
#     {'player_name': 'ClÃ©ment Grenier', 'player_goals': 1.0},
#     {'player_name': 'Pablo Maffeo', 'player_goals': 1.0},
#     {'player_name': 'Franco Russo', 'player_goals': 1.0},
#     {'player_name': 'Giovanni GonzÃ¡lez', 'player_goals': 1.0},
#     {'player_name': 'Iddrisu Baba', 'player_goals': 1.0},
#     {'player_name': 'Antonio SÃ¡nchez', 'player_goals': 1.0},
#     {'player_name': 'Alejandro Pozo Pozo', 'player_goals': 1.0},
#     {'player_name': 'Lee Kangin', 'player_goals': 1.0}]},
#   {'squad_name': 'Elche',
#    'squad_goals': 74.0,
#    'players': [{'player_name': 'Lucas BoyÃ©', 'player_goals': 14.0},
#     {'player_name': 'Pere Milla', 'player_goals': 12.0},
#     {'player_name': 'Fidel', 'player_goals': 11.0},
#     {'player_name': 'Josan', 'player_goals': 6.0},
#     {'player_name': 'Tete Morente', 'player_goals': 5.0},
#     {'player_name': 'Guido Carrillo', 'player_goals': 5.0},
#     {'player_name': 'RaÃºl Guti', 'player_goals': 3.0},
#     {'player_name': 'Lucas PÃ©rez', 'player_goals': 2.0},
#     {'player_name': 'Johan Mojica', 'player_goals': 2.0},
#     {'player_name': 'Kike PÃ©rez', 'player_goals': 2.0},
#     {'player_name': 'Dani Calvo', 'player_goals': 2.0},
#     {'player_name': 'DarÃ\xado Benedetto', 'player_goals': 2.0},
#     {'player_name': 'Enzo Roco', 'player_goals': 1.0},
#     {'player_name': 'Emiliano Rigoni', 'player_goals': 1.0},
#     {'player_name': 'Diego GonzÃ¡lez', 'player_goals': 1.0},
#     {'player_name': 'Ezequiel Ponce', 'player_goals': 1.0},
#     {'player_name': 'Lucas Olaza', 'player_goals': 1.0},
#     {'player_name': 'Pedro Bigas', 'player_goals': 1.0}]},
#   {'squad_name': 'CÃ¡diz',
#    'squad_goals': 71.0,
#    'players': [{'player_name': 'Ã\x81lvaro Negredo', 'player_goals': 15.0},
#     {'player_name': 'Anthony Lozano', 'player_goals': 10.0},
#     {'player_name': 'Ã\x81lex FernÃ¡ndez', 'player_goals': 7.0},
#     {'player_name': 'RubÃ©n Sobrino', 'player_goals': 5.0},
#     {'player_name': 'Salvi', 'player_goals': 4.0},
#     {'player_name': 'Lucas PÃ©rez', 'player_goals': 3.0},
#     {'player_name': 'IvÃ¡n Alejo', 'player_goals': 3.0},
#     {'player_name': 'Cala', 'player_goals': 3.0},
#     {'player_name': 'Marcos Mauro LÃ³pez GutiÃ©rrez', 'player_goals': 2.0},
#     {'player_name': 'Ã\x81lvaro GimÃ©nez', 'player_goals': 2.0},
#     {'player_name': 'RubÃ©n Alcaraz', 'player_goals': 2.0},
#     {'player_name': 'Alfonso Espino', 'player_goals': 2.0},
#     {'player_name': 'Alberto Perea', 'player_goals': 2.0},
#     {'player_name': 'Varazdat Haroyan', 'player_goals': 1.0},
#     {'player_name': 'JosÃ© Mari', 'player_goals': 1.0},
#     {'player_name': 'Ivan Å\xa0aponjiÄ‡', 'player_goals': 1.0},
#     {'player_name': 'Jorge Pombo', 'player_goals': 1.0},
#     {'player_name': 'Jairo Izquierdo', 'player_goals': 1.0},
#     {'player_name': 'Oussama Idrissi', 'player_goals': 1.0},
#     {'player_name': 'Santiago Arzamendia', 'player_goals': 1.0},
#     {'player_name': 'Carlos Akapo', 'player_goals': 1.0}]},
#   {'squad_name': 'La CoruÃ±a',
#    'squad_goals': 38.0,
#    'players': [{'player_name': 'AdriÃ¡n LÃ³pez', 'player_goals': 9.0},
#     {'player_name': 'Lucas PÃ©rez', 'player_goals': 8.0},
#     {'player_name': 'Florin Andone', 'player_goals': 7.0},
#     {'player_name': 'Celso Borges', 'player_goals': 3.0},
#     {'player_name': 'Borja Valle', 'player_goals': 3.0},
#     {'player_name': 'Federico Cartabia', 'player_goals': 2.0},
#     {'player_name': 'Fabian SchÃ¤r', 'player_goals': 2.0},
#     {'player_name': 'Sidnei', 'player_goals': 1.0},
#     {'player_name': 'RaÃºl Albentosa', 'player_goals': 1.0},
#     {'player_name': 'Luisinho', 'player_goals': 1.0},
#     {'player_name': 'Emre Ã‡olak', 'player_goals': 1.0}]},
#   {'squad_name': 'LeganÃ©s',
#    'squad_goals': 30.0,
#    'players': [{'player_name': 'Youssef En-Nesyri', 'player_goals': 13.0},
#     {'player_name': 'Ã“scar RodrÃ\xadguez Arnaiz', 'player_goals': 13.0},
#     {'player_name': 'Martin Braithwaite', 'player_goals': 10.0},
#     {'player_name': 'Guido Carrillo', 'player_goals': 7.0},
#     {'player_name': 'Nabil El Zhar', 'player_goals': 6.0},
#     {'player_name': 'Miguel Ã\x81ngel Guerrero', 'player_goals': 5.0},
#     {'player_name': 'Gabriel', 'player_goals': 5.0},
#     {'player_name': 'Javier Eraso', 'player_goals': 4.0},
#     {'player_name': 'Jonathan Silva', 'player_goals': 4.0},
#     {'player_name': 'Alexander', 'player_goals': 2.0},
#     {'player_name': 'Diego Rico', 'player_goals': 2.0},
#     {'player_name': 'Darko BraÅ¡anac', 'player_goals': 2.0},
#     {'player_name': 'Claudio Beauvue', 'player_goals': 2.0},
#     {'player_name': 'Gerard Gumbau', 'player_goals': 2.0},
#     {'player_name': 'Dimitris Siovas', 'player_goals': 2.0},
#     {'player_name': 'Nordin Amrabat', 'player_goals': 2.0},
#     {'player_name': 'Roger AssalÃ©', 'player_goals': 2.0},
#     {'player_name': 'Unai Bustinza', 'player_goals': 2.0},
#     {'player_name': 'Mikel Vesga', 'player_goals': 1.0},
#     {'player_name': 'RubÃ©n PÃ©rez', 'player_goals': 1.0},
#     {'player_name': 'Roque Mesa', 'player_goals': 1.0},
#     {'player_name': 'Naranjo', 'player_goals': 1.0},
#     {'player_name': 'Michael Santos', 'player_goals': 1.0},
#     {'player_name': 'MartÃ\xadn Mantovani', 'player_goals': 1.0},
#     {'player_name': 'Kenneth Omeruo', 'player_goals': 1.0},
#     {'player_name': 'KÃ©vin Rodrigues', 'player_goals': 1.0},
#     {'player_name': 'Juanfran', 'player_goals': 1.0},
#     {'player_name': 'Joseba ZaldÃºa', 'player_goals': 1.0},
#     {'player_name': 'Javier AvilÃ©s', 'player_goals': 1.0},
#     {'player_name': 'Bryan', 'player_goals': 1.0},
#     {'player_name': 'Allan Nyom', 'player_goals': 1.0}]},
#   {'squad_name': 'Las Palmas',
#    'squad_goals': 24.0,
#    'players': [{'player_name': 'Jonathan Calleri', 'player_goals': 9.0},
#     {'player_name': 'LoÃ¯c RÃ©my', 'player_goals': 5.0}]},
#   {'squad_name': 'MÃ¡laga',
#    'squad_goals': 24.0,
#    'players': [{'player_name': 'Diego RolÃ¡n', 'player_goals': 5.0},
#     {'player_name': 'Youssef En-Nesyri', 'player_goals': 4.0},
#     {'player_name': 'Chory Castro', 'player_goals': 4.0}]},
#   {'squad_name': 'Las Palmas',
#    'squad_goals': 24.0,
#    'players': [{'player_name': 'Jonathan Viera', 'player_goals': 4.0}]},
#   {'squad_name': 'MÃ¡laga',
#    'squad_goals': 24.0,
#    'players': [{'player_name': 'AdriÃ¡n GonzÃ¡lez', 'player_goals': 3.0}]},
#   {'squad_name': 'Las Palmas',
#    'squad_goals': 24.0,
#    'players': [{'player_name': 'Alen HaliloviÄ‡', 'player_goals': 2.0}]},
#   {'squad_name': 'MÃ¡laga',
#    'squad_goals': 24.0,
#    'players': [{'player_name': 'Borja BastÃ³n', 'player_goals': 2.0}]},
#   {'squad_name': 'Las Palmas',
#    'squad_goals': 24.0,
#    'players': [{'player_name': 'David GarcÃ\xada', 'player_goals': 1.0},
#     {'player_name': 'Erik ExpÃ³sito', 'player_goals': 1.0}]},
#   {'squad_name': 'MÃ¡laga',
#    'squad_goals': 24.0,
#    'players': [{'player_name': 'Diego GonzÃ¡lez', 'player_goals': 1.0}]},
#   {'squad_name': 'Las Palmas',
#    'squad_goals': 24.0,
#    'players': [{'player_name': 'Vitolo', 'player_goals': 1.0},
#     {'player_name': 'Tana', 'player_goals': 1.0}]},
#   {'squad_name': 'MÃ¡laga',
#    'squad_goals': 24.0,
#    'players': [{'player_name': 'Roberto Rosales', 'player_goals': 1.0},
#     {'player_name': 'Brown Ideye', 'player_goals': 1.0},
#     {'player_name': 'Paul Baysse', 'player_goals': 1.0},
#     {'player_name': 'Recio', 'player_goals': 1.0}]}]}

# %%
labels = []
parents = []
values = []
labels.append(result['league_name'])
parents.append('')
values.append(result['league_goals'])
for team in result['teams']:
    team_name = team['squad_name']
    labels.append(team_name)
    parents.append(result['league_name'])
    team_goals = team['squad_goals']
    values.append(team_goals)
    for j in range(2):
        player_name = team['players'][j]['player_name']
        labels.append(player_name)
        parents.append(team_name)
        player_goals = team['players'][j]['player_goals']
        values.append(player_goals)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/q6/2rkffy0d4fq7d4cjm8lnbgsw0000gn/T/ipykernel_90734/742888110.py in <module>
#      12     values.append(team_goals)
#      13     for j in range(2):
# ---> 14         player_name = team['players'][j]['player_name']
#      15         labels.append(player_name)
#      16         parents.append(team_name)
#
# IndexError: list index out of range

# %%
# print(labels)
# print(parents)
# print(values)

team_player_goals = {'labels': labels,
                     'parents': parents,
                     'values': values}
team_player_goals

# %%
# values = []
# labels = []
# parents = []

# for league in leagues: 
#     values.push(league.goals)
#     labels.push(League.name)
#     parents.push("")
#     for team in league: 
#          values.push(team.goals)
#          labels.push(team.name)
#          parents.push(league.name)
#          for player in team: 
#                values.push(player.goals)
#                labels.push(player.name) 
#                parents.push(team.name)

# for key in my_dict:
#     # Check if the key value has changed
#     if key != prev_key:
#         print(“Key value changed from”, prev_key, “to”, key)
#     # Update previous key value
#     prev_key = key

# %%
#league_wage_pts = {}
total_goals_dict = {}
goals_dict = {}
goals_list = []

for row in response_sunburst:
    league_name = row.league
    league_total_goals = row.league_total_goals
    goals_dict['squad_name'] = row.squad
    goals_dict['squad_goals'] = row.squad_total_goals
    goals_dict['player_name'] = row.player
    goals_dict['player_goals'] = row.player_total_goal
    goals_list.append(goals_dict)

total_goals_dict['league_name'] = league_name
total_goals_dict['league_total_goals'] = league_total_goals
total_goals_dict['squad'] = goals_list
pprint(total_goals_dict)

# %%
columns_wages = inspector.get_columns('league_wages')
for column in columns_wages:
    print(column['name'], column['type'])
# Out:
# league VARCHAR(255)
# avgofannual_wages DOUBLE_PRECISION
# squad VARCHAR(255)
# wages_rank INTEGER
# id INTEGER

# %%
columns_pts = inspector.get_columns('league_pts')
for column in columns_pts:
    print(column['name'], column['type'])
# Out:
# league VARCHAR(255)
# avg_pts DOUBLE_PRECISION
# squad VARCHAR(255)
# pts_rank INTEGER
# id INTEGER

# %%
response_wages_pts = session.query(Wages.league,Wages.avgofannual_wages, Wages.squad, Points.avg_pts).join(Points, Wages.squad == Points.squad).order_by(Wages.league.asc(), Points.avg_pts.desc()).all()

response_wages_pts[:3]
# Out:
# [('Bundesliga', 214600262.6, 'Bayern Munich', 79.8),
#  ('Bundesliga', 95156702.6, 'Dortmund', 66.6),
#  ('Bundesliga', 56206762.0, 'RB Leipzig', 61.6)]

# %%
leagues = set(league for league, _, _, _ in response_wages_pts)
leagues
# Out:
# {'Bundesliga', 'EPL', 'LaLiga', 'Ligue1', 'SerieA'}

# %%
wage_point = []
for league_name in leagues:
    league_dict = {
        'league': league_name,
        'teams': {
            'squad_name': [],
            'avg_wage': [],
            'points': []
        }
    }
    for league, squad_name, wage, point in response_wages_pts:
        if league == league_name:
            league_dict['teams']['squad_name'].append(squad_name)
            league_dict['teams']['avg_wage'].append(wage)
            league_dict['teams']['points'].append(point)
    
    wage_point.append(league_dict)

# %%
wage_point
# Out:
# [{'league': 'EPL',
#   'teams': {'squad_name': [179932697.0,
#     149067536.8,
#     175604562.4,
#     222433114.8,
#     127294420.2,
#     163805984.4,
#     89788562.8,
#     60791683.5,
#     89407711.8,
#     107874700.0,
#     29163122.5,
#     25677627.0,
#     92044989.2,
#     69386704.0,
#     74838599.6666667,
#     48016067.4,
#     73859079.0,
#     55778389.4,
#     55941092.3333333,
#     26897219.5,
#     59218946.25,
#     40090150.0,
#     58054764.0,
#     59609032.0,
#     58417020.5,
#     62637256.5,
#     36895335.5,
#     34943688.5],
#    'avg_wage': ['Manchester City',
#     'Liverpool',
#     'Chelsea',
#     'Manchester Utd',
#     'Tottenham',
#     'Arsenal',
#     'Leicester City',
#     'Wolves',
#     'West Ham',
#     'Everton',
#     'Leeds United',
#     'Brentford',
#     'Crystal Palace',
#     'Newcastle Utd',
#     'Aston Villa',
#     'Burnley',
#     'Southampton',
#     'Brighton',
#     'Bournemouth',
#     'Sheffield Utd',
#     'Watford',
#     'Cardiff City',
#     'Swansea City',
#     'Stoke City',
#     'West Brom',
#     'Fulham',
#     'Huddersfield',
#     'Norwich City'],
#    'points': [91.6,
#     86.4,
#     69.8,
#     69.0,
#     68.0,
#     63.8,
#     55.8,
#     53.0,
#     50.8,
#     50.0,
#     48.5,
#     46.0,
#     45.6,
#     45.4,
#     45.0,
#     44.4,
#     42.0,
#     41.8,
#     41.0,
#     38.5,
#     37.0,
#     34.0,
#     33.0,
#     33.0,
#     28.5,
#     27.0,
#     26.5,
#     21.5]}},
#  {'league': 'Bundesliga',
#   'teams': {'squad_name': [214600262.6,
#     95156702.6,
#     56206762.0,
#     56000901.0,
#     49089490.0,
#     38849964.2,
#     42290893.2,
#     20433189.6666667,
#     63199947.4,
#     15936971.2,
#     13768197.0,
#     21579385.0,
#     34358841.25,
#     25449741.75,
#     37924307.0,
#     56765032.25,
#     18905798.0,
#     23492258.4,
#     32381509.25,
#     10303219.5,
#     34882158.0,
#     7143974.0,
#     11176598.0,
#     12942721.0],
#    'avg_wage': ['Bayern Munich',
#     'Dortmund',
#     'RB Leipzig',
#     'Leverkusen',
#     "M'Gladbach",
#     'Eint Frankfurt',
#     'Hoffenheim',
#     'Union Berlin',
#     'Wolfsburg',
#     'Freiburg',
#     'Bochum',
#     'Mainz 05',
#     'Werder Bremen',
#     'Stuttgart',
#     'Hertha BSC',
#     'Schalke 04',
#     'DÃ¼sseldorf',
#     'Augsburg',
#     'KÃ¶ln',
#     'Arminia',
#     'Hamburger SV',
#     'Paderborn 07',
#     'NÃ¼rnberg',
#     'Greuther FÃ¼rth'],
#    'points': [79.8,
#     66.6,
#     61.6,
#     58.4,
#     52.2,
#     50.0,
#     49.4,
#     49.3333333333333,
#     48.0,
#     44.0,
#     42.0,
#     40.2,
#     39.25,
#     39.25,
#     39.0,
#     37.75,
#     37.0,
#     36.6,
#     35.75,
#     31.5,
#     31.0,
#     20.0,
#     19.0,
#     18.0]}},
#  {'league': 'LaLiga',
#   'teams': {'squad_name': [297759978.4,
#     291618608.4,
#     163951428.8,
#     82376021.2,
#     70072285.4,
#     44880863.6,
#     72550359.2,
#     37822700.2,
#     57305466.2,
#     25170427.4,
#     19098153.3333333,
#     25454012.3333333,
#     46892590.4,
#     16376107.5,
#     25232595.8,
#     19185032.75,
#     32068896.75,
#     20056120.0,
#     22370928.8,
#     16723621.5,
#     18605584.0,
#     16010245.0,
#     35995024.0,
#     17279040.0,
#     16635470.0,
#     21461472.0,
#     20080579.0,
#     25449261.0],
#    'avg_wage': ['Barcelona',
#     'Real Madrid',
#     'AtlÃ©tico Madrid',
#     'Sevilla',
#     'Villarreal',
#     'Real Sociedad',
#     'Valencia',
#     'Betis',
#     'Athletic Club',
#     'Getafe',
#     'Osasuna',
#     'Granada',
#     'Celta Vigo',
#     'Girona',
#     'Levante',
#     'Eibar',
#     'Espanyol',
#     'CÃ¡diz',
#     'AlavÃ©s',
#     'Elche',
#     'Valladolid',
#     'Rayo Vallecano',
#     'LeganÃ©s',
#     'Mallorca',
#     'Huesca',
#     'La CoruÃ±a',
#     'Las Palmas',
#     'MÃ¡laga'],
#    'points': [82.8,
#     80.2,
#     76.4,
#     66.8,
#     56.4,
#     55.8,
#     55.6,
#     55.4,
#     49.6,
#     49.0,
#     47.6666666666667,
#     46.6666666666667,
#     45.2,
#     44.0,
#     43.0,
#     42.5,
#     42.25,
#     41.5,
#     41.0,
#     39.0,
#     38.0,
#     37.0,
#     36.0,
#     36.0,
#     33.5,
#     29.0,
#     22.0,
#     20.0]}},
#  {'league': 'SerieA',
#   'teams': {'squad_name': [210186081.2,
#     123290501.2,
#     98757631.4,
#     107143493.2,
#     38519975.2,
#     71988418.8,
#     103369110.0,
#     47466756.4,
#     32067979.0,
#     45278725.0,
#     36558183.4,
#     34034253.0,
#     25541179.4,
#     24403904.25,
#     28833726.5,
#     39081303.2,
#     40849256.8,
#     18690509.0,
#     32249449.6666667,
#     32937690.0,
#     25526712.3333333,
#     23490524.0,
#     14927945.5,
#     19094074.0,
#     25546072.5,
#     23368232.0,
#     22931028.0,
#     16499416.0],
#    'avg_wage': ['Juventus',
#     'Inter',
#     'Napoli',
#     'Milan',
#     'Atalanta',
#     'Lazio',
#     'Roma',
#     'Fiorentina',
#     'Sassuolo',
#     'Torino',
#     'Sampdoria',
#     'Bologna',
#     'Udinese',
#     'Hellas Verona',
#     'Empoli',
#     'Cagliari',
#     'Genoa',
#     'Spezia',
#     'Parma',
#     'Lecce',
#     'SPAL',
#     'Salernitana',
#     'Crotone',
#     'Chievo',
#     'Benevento',
#     'Venezia',
#     'Frosinone',
#     'Brescia'],
#    'points': [83.2,
#     79.6,
#     77.6,
#     72.6,
#     68.8,
#     68.2,
#     67.6,
#     49.8,
#     49.8,
#     48.8,
#     47.4,
#     43.4,
#     43.0,
#     43.0,
#     39.5,
#     38.4,
#     37.6,
#     37.5,
#     36.6666666666667,
#     35.0,
#     33.3333333333333,
#     31.0,
#     29.0,
#     28.5,
#     27.0,
#     27.0,
#     25.0,
#     25.0]}},
#  {'league': 'Ligue1',
#   'teams': {'squad_name': [294309377.8,
#     41251695.2,
#     58144648.8,
#     51527008.8,
#     3475017.66666667,
#     25880288.0,
#     22218438.2,
#     26975966.6,
#     21374085.25,
#     12574777.6,
#     10685204.0,
#     15344930.4,
#     4717418.5,
#     8415243.4,
#     18499666.0,
#     12058638.0,
#     7958994.33333333,
#     9055199.0,
#     3654049.0,
#     14451503.3333333,
#     12149626.2,
#     13069600.0,
#     11660168.5,
#     11214305.0,
#     11565218.3333333,
#     5288560.66666667,
#     412543.0,
#     2309378.0],
#    'avg_wage': ['Paris S-G',
#     'Lyon',
#     'Marseille',
#     'Monaco',
#     'Lens',
#     'Lille',
#     'Rennes',
#     'Nice',
#     'Saint-Ã‰tienne',
#     'Montpellier',
#     'Reims',
#     'Nantes',
#     'NÃ®mes',
#     'Strasbourg',
#     'Bordeaux',
#     'Amiens',
#     'Lorient',
#     'Brest',
#     'Clermont Foot',
#     'Toulouse',
#     'Angers',
#     'Guingamp',
#     'Caen',
#     'Metz',
#     'Dijon',
#     'Troyes',
#     'Auxerre',
#     'Ajaccio'],
#    'points': [84.2,
#     66.8,
#     66.0,
#     64.2,
#     60.6666666666667,
#     60.6,
#     56.8,
#     54.6,
#     49.75,
#     48.8,
#     47.5,
#     45.2,
#     44.0,
#     43.6,
#     43.0,
#     41.5,
#     41.0,
#     39.0,
#     38.0,
#     37.6666666666667,
#     37.2,
#     37.0,
#     35.5,
#     34.6666666666667,
#     34.3333333333333,
#     30.6666666666667,
#     29.0,
#     21.0]}}]

# %%
league_wages_pts_df = pd.DataFrame(response_wages_pts, columns = ['league', 'avg_wage', 'squad_name', 'avg_points'])
league_wages_pts_df.head()

# %%
league_wages_pts_df.isna().sum()

# %%
league_wage_pts = {}
squad_names = []
avg_wages = []
avg_points = []
for row in response_wages_pts:
    squad_name = row.squad
    wage = row.avgofannual_wages
    point = row.avg_pts
    squad_names.append(squad_name)
    avg_wages.append(wage)
    avg_points.append(point)

league_wage_pts['league'] = 'league'
league_wage_pts['squad_name'] = squad_names
league_wage_pts['avg_wage'] = avg_wages
league_wage_pts['points'] = avg_points
league_wage_pts

# %%
session = Session(engine)
response_stadiums = session.query(Stadiums.city, Stadiums.club, Stadiums.stadium, Stadiums.cap,
                      Stadiums.country, Stadiums.longitude, Stadiums.latitude, Stadiums.trivia, Stadiums.league).all()
print(response_stadiums)

# %%
features = []
for row in response_stadiums:
    properties = {
        'City': row.city,
        'Stadium name': row.stadium,
        'Squad name': row.club,
        'Capacity': row.cap,
        'Stadium fact': row.trivia
    }
    geometry = {
        'type': 'Point',
        'coordinates': [row.latitude, row.longitude]
    }
    feature = {
        'type': 'Feature',
        'geometry': geometry,
        'properties': properties
    }
    features.append(feature)
geojson_data = {
    'type': 'FeatureCollection',
    'features': features
}

pprint(geojson_data)

# %%
session.close()
