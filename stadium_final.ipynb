# %% [markdown]
# ## Scrape and Analyze Stadium Data from stadiumguide.com website
# Create a Beautiful Soup object and use it to scrape the data in the HTML table

# %%
# importing required libraries

import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as soup
from splinter import Browser

# %%
browser = Browser('chrome')

# %% [markdown]
# #### Challenge in retrieving trivia for the stadium was that in stradium table, on clicking stadium name, the url of the page containing description about the stadium did not have the stadium name consistent with the stadium name on home page. E.g. The stadium name  on the home page www.stadiumguide.com is `Estadio ABANCA-Riazor` but the stadium description url for the stadium https://www.stadiumguide.com/riazor/ contains `riazor`. So we accessed the href links in all the `a` tags on home page and then using those href urls we accessesd the stadium page to get the trivia

# %%
# Looping through each country to get the stadium page links and stadiums list
countries = ["england", "france", "germany", "italy", "spain"]
base_url = "https://www.stadiumguide.com/present/"

hrefs_list = []
stadiums = []

for country in countries:
    final_url = f'{base_url}{country}'
    browser.visit(final_url)
    browser.is_element_present_by_css('div.site', wait_time=1)
    html = browser.html
    try:
        stadium_soup = soup(html, 'html.parser')
        stadium_table = stadium_soup.find('tbody')
        a_tags = stadium_table.find_all('a')
        for tag in a_tags:
            hrefs_list.append(tag['href'])
            stadiums.append(tag.text) 
    except Exception as e:
        print(e)

# %%
print(len(hrefs_list))
print(len(stadiums))
# Out:
# 236
# 236

# %%
stadiums
# Out:
# ['Oakwell Stadium',
#  'Villa Park',
#  "St Andrew's Stadium",
#  'Ewood Park',
#  'Bloomfield Road',
#  'University of Bolton Stadium',
#  'Vitality Stadium',
#  'Coral Windows Stadium',
#  'The Amex',
#  'Ashton Gate Stadium',
#  'Memorial Stadium',
#  'Turf Moor',
#  'Gigg Lane',
#  'Coventry Building Society Arena',
#  'Victoria Road',
#  'The iPro Stadium',
#  'Keepmoat Stadium',
#  'Highbury Stadium',
#  'Priestfield Stadium',
#  "John Smith's Stadium",
#  'MKM Stadium',
#  'Portman Road',
#  'Elland Road',
#  'King Power Stadium',
#  'Goodison Park',
#  'Anfield',
#  'Emirates Stadium',
#  'Brentford Community Stadium',
#  'The Valley',
#  'Stamford Bridge',
#  'Selhurst Park',
#  'Craven Cottage',
#  'The Matchroom Stadium',
#  'The Den',
#  'Loftus Road',
#  'Tottenham Hotspur Stadium',
#  'London Stadium',
#  'Wembley Stadium',
#  'Kenilworth Road',
#  'Etihad Stadium',
#  'Old Trafford',
#  'Riverside Stadium',
#  'St James Park',
#  'Carrow Road',
#  'City Ground',
#  'Meadow Lane',
#  'The Kassam Stadium',
#  'ABAX Stadium',
#  'Fratton Park',
#  'Deepdale',
#  'Madejski Stadium',
#  'Crown Oil Arena',
#  'New York Stadium',
#  'Glanford Park',
#  'Bramall Lane',
#  'Hillsborough',
#  'Montgomery Waters Stadium',
#  "St Mary's Stadium",
#  'Roots Hall Stadium',
#  'The Lamex Stadium',
#  'bet365 Stadium',
#  'Stadium of Light',
#  'Vicarage Road',
#  'The Hawthorns',
#  'DW Stadium',
#  'Molineux Stadium',
#  'Stade Francois Coty',
#  'Stade de la Licorne',
#  'Stade Raymond Kopa',
#  'Parc des Sports',
#  'Stade Abbe Deschamps',
#  'Stade Armand Cesari',
#  'Matmut Atlantique',
#  'Stade Chaban-Delmas',
#  'Stade Marcel Verchere',
#  'Stade Francis-Le Ble',
#  "Stade Michel d'Ornano",
#  'Stade Gaston Petit',
#  'Stade Gaston-Gerard',
#  'Stade des Alpes',
#  'Stade du Roudourou',
#  'Stade Oceane',
#  'MMArena',
#  'Stade Bollaert-Delelis',
#  'Stade Pierre Mauroy',
#  'Stade du Moustoir',
#  'Groupama Stadium',
#  'Stade Gerland',
#  'Orange Velodrome',
#  'Stade Saint-Symphorien',
#  'Stade Louis II',
#  'Stade Auguste Bonal',
#  'Stade de la Mosson',
#  'Stade Marcel-Picot',
#  'Stade de La Beaujoire',
#  'Allianz Riviera',
#  'Stade des Costieres',
#  'Stade Rene Gaillard',
#  'Stade Charlety',
#  'Parc des Princes',
#  'Stade Auguste Delaune',
#  'Roazhon Park',
#  'Stade de France',
#  'Stade Geoffroy Guichard',
#  'Stade de la Meinau',
#  'Stadium de Toulouse',
#  "Stade de l'Aube",
#  'Stade du Hainaut',
#  'Tivoli',
#  'Erzgebirgsstadion',
#  'WWK Arena',
#  'Stadion An der Alten Försterei',
#  'Olympiastadion',
#  'SchucoArena',
#  'Vonovia Ruhrstadion',
#  'Weserstadion',
#  'Eintracht-Stadion',
#  'RheinEnergieStadion',
#  'Stadion der Freundschaft',
#  'Stadion am Bollenfalltor',
#  'Signal Iduna Park',
#  'Rudolf-Harbig-Stadion',
#  'Schauinsland-Reisen-Stadion',
#  'Merkur Spiel Arena',
#  'Stadion Essen',
#  'Deutsche Bank Park',
#  'Schwarzwald-Stadion',
#  'Sportpark Ronhof',
#  'VELTINS-Arena',
#  'Volksparkstadion',
#  'Millerntor-Stadion',
#  'HDI Arena',
#  'Audi Sportpark',
#  'Fritz-Walter-Stadion',
#  'Holstein-Stadion',
#  'Red Bull Arena',
#  'BayArena',
#  'MDCC-Arena',
#  'MEWA Arena',
#  'Bruchwegstadion',
#  'Borussia-Park',
#  'Allianz Arena',
#  'Grunwalder Stadion',
#  'Olympiastadion Munich',
#  'Max-Morlock-Stadion',
#  'Benteler-Arena',
#  'Jahnstadion Regensburg',
#  'PreZero Arena',
#  'Mercedes-Benz Arena',
#  'BRITA-Arena',
#  'Volkswagen Arena',
#  'Stadio San Nicola',
#  'Stadio Ciro Vigorito',
#  "Stadio Atleti Azzurri d'Italia",
#  "Stadio Renato Dall'Ara",
#  'Stadio Mario Rigamonti',
#  "Stadio Sant'Elia",
#  'Stadio Angelo Massimio',
#  'Stadio G. Sinigaglia',
#  'Stadio Giovanni Zini',
#  'Stadio Ezio Scida',
#  'Stadio Carlo Castellani',
#  'Stadio Paolo Mazza',
#  'Stadio Artemio Franchi',
#  'Stadio Benito Stirpe',
#  'Stadio Luigi Ferraris',
#  'Stadio Alberto Picco',
#  'Stadio Via Del Mare',
#  'Stadio Armando Picchi',
#  'San Siro',
#  'Stadio Alberto Braglia',
#  'Stadio Brianteo',
#  'Stadio San Paolo',
#  'Stadio Silvio Piola',
#  'Stadio Euganeo',
#  'Stadio Renzo Barbera',
#  'Stadio Ennio Tardini',
#  'Stadio Adriatico',
#  'Stadio Leonardo Garilli',
#  'MAPEI Stadium - Citta del Tricolore',
#  'Stadio Olimpico',
#  'Stadio Artemio Franchi',
#  'Allianz Stadium',
#  'Stadio Olimpico di Torino',
#  'Stadio Friuli',
#  'Stadio Franco Ossola',
#  'Stadio Pierluigi Penzo',
#  'Stadio Marcantonio Bentegodi',
#  'Estadio ABANCA-Riazor',
#  'Estadio Municipal de Santo Domingo',
#  'Estadio Jose Rico Perez',
#  'Estadio de los Juegos Mediterraneos',
#  'Campo de Lasesarre',
#  'Camp Nou',
#  'RCDE Stadium',
#  'Estadio San Mames',
#  'Nuevo Estadio Ramon de Carranza',
#  'Estadio Cartagonova',
#  'Estadio El Arcangel',
#  'Estadio de Ipurua',
#  'Estadio Martinez Valero',
#  'Coliseum Alfonso Perez',
#  'Estadio El Molinon',
#  'Estadi Municipal de Montilivi',
#  'Estadio de Los Carmenes',
#  'Estadio El Alcoraz',
#  'Stadium Gal',
#  'Estadio de Gran Canaria',
#  'Estadio Municipal de Butarque',
#  'Estadio Las Gaunas',
#  'Wanda Metropolitano',
#  'Campo de Futbol de Vallecas',
#  'Estadio Santiago Bernabeu',
#  'Estadio Alfredo di Stefano',
#  'Estadio La Rosaleda',
#  'Estadio Enrique Roca de Murcia',
#  'Estadio Carlos Tartiere',
#  'Iberostar Estadio',
#  'Estadio El Sadar',
#  'Estadio Municipal El Toralin',
#  'Estadi Municipal de la Nova Creu Alta',
#  'Reale Arena',
#  'Estadio Heliodoro Rodriguez Lopez',
#  'Campos de Sport de El Sardinero',
#  'Estadio La Cartuja de Sevilla',
#  'Estadio Benito Villamarin',
#  'Estadio Ramon Sanchez Pizjuan',
#  'Nuevo Estadio Los Pajaritos',
#  'Nou Estadi',
#  'Estadi Ciutat de Valencia',
#  'Estadio de Mestalla',
#  'Estadio Jose Zorrilla',
#  'Estadio El Madrigal',
#  'Estadio Municipal de Balaidos',
#  'Estadio de Mendizorroza',
#  'Estadio La Romareda']

# %%
stadium_links_df = pd.DataFrame({'Stadium': stadiums, 'Trivia Page link': hrefs_list})
stadium_links_df.sample(10)
# Out:
#                           Stadium
# 187  Stadio Marcantonio Bentegodi  \
# 98                 Stade Charlety
# 225     Estadio Benito Villamarin
# 142            Grunwalder Stadion
# 216       Estadio Carlos Tartiere
# 182               Allianz Stadium
# 51                Crown Oil Arena
# 121         Rudolf-Harbig-Stadion
# 50               Madejski Stadium
# 150              Volkswagen Arena
#
#                                       Trivia Page link
# 187            https://www.stadiumguide.com/bentegodi/
# 98        https://www.stadiumguide.com/stade-charlety/
# 225     https://www.stadiumguide.com/benitovillamarin/
# 142   https://www.stadiumguide.com/grunwalder-stadion/
# 216  https://www.stadiumguide.com/estadio-carlos-ta...
# 182      https://www.stadiumguide.com/juventusstadium/
# 51       https://www.stadiumguide.com/crown-oil-arena/
# 121     https://www.stadiumguide.com/glucksgasstadion/
# 50              https://www.stadiumguide.com/madejski/
# 150      https://www.stadiumguide.com/volkswagenarena/

# %%
trivia_list =[]
for link in hrefs_list[:50]:
    browser.visit(link)
    browser.is_element_present_by_css('div.site', wait_time=1)
    trivia_html = browser.html
    try:
        trivia_soup = soup(trivia_html, 'html.parser')
        trivias = trivia_soup.find('section', class_='entry-content').find_all('p')
        trivia = trivias[2].text
        trivia_list.append(trivia) 
    except Exception as e:
        print(e)

# print(f'Number of Stadiums: {len(stadiums)}')
# print('First 3 stadiums in the list are:')      
# for stadium in stadiums[:3]:
#     print(stadium)
# print('-'*50)
# print(f'Number of Trivias: {len(trivia_list)}')
# print('Trivia on first 3 stadiums in the list are:')
# for trivia in trivia_list:
#     print(trivia)

# %%
len(trivia_list)
# Out:
# 50

# %%
for link in hrefs_list[50:100]:
    browser.visit(link)
    browser.is_element_present_by_css('div.site', wait_time=1)
    trivia_html = browser.html
    try:
        trivia_soup = soup(trivia_html, 'html.parser')
        trivias = trivia_soup.find('section', class_='entry-content').find_all('p')
        trivia = trivias[2].text
        trivia_list.append(trivia) 
    except Exception as e:
        print(e)

# %%
len(trivia_list)
# Out:
# 100

# %%
for link in hrefs_list[100:150]:
    browser.visit(link)
    browser.is_element_present_by_css('div.site', wait_time=1)
    trivia_html = browser.html
    try:
        trivia_soup = soup(trivia_html, 'html.parser')
        trivias = trivia_soup.find('section', class_='entry-content').find_all('p')
        trivia = trivias[2].text
        trivia_list.append(trivia) 
    except Exception as e:
        print(e)

# %%
len(trivia_list)
# Out:
# 150

# %%
for link in hrefs_list[150:200]:
    browser.visit(link)
    browser.is_element_present_by_css('div.site', wait_time=1)
    trivia_html = browser.html
    try:
        trivia_soup = soup(trivia_html, 'html.parser')
        trivias = trivia_soup.find('section', class_='entry-content').find_all('p')
        trivia = trivias[2].text
        trivia_list.append(trivia) 
    except Exception as e:
        print(e)

# %%
len(trivia_list)
# Out:
# 200

# %%
for link in hrefs_list[200:]:
    browser.visit(link)
    browser.is_element_present_by_css('div.site', wait_time=1)
    trivia_html = browser.html
    try:
        trivia_soup = soup(trivia_html, 'html.parser')
        trivias = trivia_soup.find('section', class_='entry-content').find_all('p')
        trivia = trivias[2].text
        trivia_list.append(trivia) 
    except Exception as e:
        print(e)

# %%
len(trivia_list)
# Out:
# 236

# %%
stadium_links_df['Trivia'] = trivia_list
stadium_links_df.head()
# Out:
#                Stadium                              Trivia Page link
# 0      Oakwell Stadium         https://www.stadiumguide.com/oakwell/  \
# 1           Villa Park       https://www.stadiumguide.com/villapark/
# 2  St Andrew's Stadium       https://www.stadiumguide.com/standrews/
# 3           Ewood Park       https://www.stadiumguide.com/ewoodpark/
# 4      Bloomfield Road  https://www.stadiumguide.com/bloomfieldroad/
#
#                                               Trivia
# 0  Oakwell Stadium was built in 1888. It got exte...
# 1  In the late 19th century, Villa Park was part ...
# 2  St. Andrew’s Stadium opened on the 26th of Dec...
# 3  Ewood Park developed quickly in the early 20th...
# 4  Football was first played at the site of Bloom...

# %%
stadium_df = pd.read_csv('Data/Stadium_Lat_Lng_data.csv')
stadium_df.head()
# Out:
#          City              Club              Stadium     Cap  Country
# 0    Barnsley          Barnsley      Oakwell Stadium  23,287  England  \
# 1  Birmingham       Aston Villa           Villa Park  42,785  England
# 2  Birmingham   Birmingham City  St Andrew's Stadium  30,009  England
# 3   Blackburn  Blackburn Rovers           Ewood Park  31,154  England
# 4   Blackpool         Blackpool      Bloomfield Road  16,007  England
#
#    Longitude   Latitude
# 0  -1.467725  53.552140
# 1 -87.977837  41.889312
# 2  -1.868041  52.475567
# 3  -2.489258  53.728609
# 4  -2.373736  51.365293

# %%
stadium_final_df = pd.merge(stadium_df, stadium_links_df, how='left', on="Stadium")
stadium_final_df.sample(100)
# Out:
#                 City               Club                  Stadium     Cap
# 53        Scunthorpe  Scunthorpe United            Glanford Park   9,088  \
# 15             Derby       Derby County         The iPro Stadium  33,010
# 61        Sunderland         Sunderland         Stadium of Light  49,000
# 43           Norwich       Norwich City              Carrow Road  27,010
# 121          Dresden     Dynamo Dresden    Rudolf-Harbig-Stadion  32,249
# ..               ...                ...                      ...     ...
# 7           Bradford      Bradford City    Coral Windows Stadium  25,136
# 1         Birmingham        Aston Villa               Villa Park  42,785
# 233  Vitoria-Gasteiz   Deportivo Alaves  Estadio de Mendizorroza  19,840
# 18        Gillingham      Gillingham FC      Priestfield Stadium  10,500
# 181            Siena              Siena   Stadio Artemio Franchi  15,373
#
#      Country  Longitude   Latitude
# 53   England  -0.695326  53.586813  \
# 15   England -54.715325 -61.116337
# 61   England  -1.388258  54.914395
# 43   England   1.310132  52.621983
# 121  Germany  13.748038  51.040855
# ..       ...        ...        ...
# 7    England -78.711268  26.536886
# 1    England -87.977837  41.889312
# 233    Spain  -9.260969  38.708812
# 18   England   0.560950  51.384211
# 181    Italy  11.282819  43.780884
#
#                                       Trivia Page link
# 53         https://www.stadiumguide.com/glanford-park/  \
# 15      https://www.stadiumguide.com/prideparkstadium/
# 61        https://www.stadiumguide.com/stadiumoflight/
# 43            https://www.stadiumguide.com/carrowroad/
# 121     https://www.stadiumguide.com/glucksgasstadion/
# ..                                                 ...
# 7           https://www.stadiumguide.com/valleyparade/
# 1              https://www.stadiumguide.com/villapark/
# 233  https://www.stadiumguide.com/estadio-mendizorr...
# 18   https://www.stadiumguide.com/priestfield-stadium/
# 181  https://www.stadiumguide.com/artemiofranchisiena/
#
#                                                 Trivia
# 53   Glanford Park got built in the 1980s to replac...
# 15   The iPro Stadium, previously known as Pride Pa...
# 61   The Stadium of Light was built in the mid 1990...
# 43   Norwich quickly found a new site though, and i...
# 121  By the 2000s, however, the old stadium had sig...
# ..                                                 ...
# 7    Valley Parade was then still a modest stadium,...
# 1    In the late 19th century, Villa Park was part ...
# 233  Estadio de Mendizorroza (Mendizorrotza in Basq...
# 18   Priestfield Stadium, officially MEMS Priestfie...
# 181  The stadium was initially simply called Stadio...
#
# [100 rows x 9 columns]

# %%
stadium_final_df.to_csv('Data/stadiums_final.csv', index=False)

# %%
browser.quit()
